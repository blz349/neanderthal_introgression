# %% [markdown]
# # Immune disease associations of Neanderthal-introgressed SNPs
#
# This code investigates if Neanderthal-introgressed SNPs have been associated with any immune-related diseases, including infectious diseases, allergic diseases, autoimmune diseases and autoinflammatory diseases, using data from the NHGRI-EBI GWAS Catalog.
#
# Neanderthal-introgressed SNPs from:
# 1. Dannemann M, Prufer K & Kelso J. Functional implications of Neandertal introgression in modern humans. *Genome Biol* 2017 **18**:61.
# 2. Simonti CN *et al.* The phenotypic legacy of admixture between modern humans and Neandertals. *Science* 2016 **351**:737-41.
#
# GWAS summary statistics from:
# * [GWAS Catalog](https://www.ebi.ac.uk/gwas/docs/file-downloads)

# %%
# Import modules
import pandas as pd

# %% [markdown]
# ## Get Neanderthal SNPs present in GWAS Catalog

# %%
# Load Neanderthal-introgressed SNPs
neanderthal = pd.read_csv('../neanderthal/allpop_fixed.csv', usecols=['Chromosome', 'Position', 'Source', 'ID'])

# %%
# Load GWAS catalog
catalog = pd.read_csv('GWAS_Catalog.tsv', sep="\t", header=0,
                      usecols=['DISEASE/TRAIT', 'CHR_ID', 'CHR_POS', 'REPORTED GENE(S)', 'MAPPED_GENE',
                               'STRONGEST SNP-RISK ALLELE', 'SNPS', 'RISK ALLELE FREQUENCY', 'P-VALUE', 'OR or BETA',
                               '95% CI (TEXT)', 'MAPPED_TRAIT', 'STUDY ACCESSION'], low_memory=False)
catalog = catalog.loc[catalog.CHR_ID != 'X'].copy()
catalog = catalog.loc[catalog.CHR_ID != 'Y'].copy()
catalog.rename(columns={'CHR_ID': 'Chromosome', 'CHR_POS': 'Position', 'SNPS': 'ID'}, inplace=True)

# %%
# Neanderthal SNPs present in GWAS catalog
nean_catalog = neanderthal.merge(catalog.drop(columns=['Chromosome', 'Position']), how='inner', on='ID')
nean_catalog
# Out:
#       Chromosome  Position          Source           ID  \
# 0              1   3431555            both     rs947350
# 1              1   3651409            both   rs10910018
# 2              1   3651409            both   rs10910018
# 3              1   4449204            both   rs72632736
# 4              1   9472981            both  rs118100927
# ...          ...       ...             ...          ...
# 1306          22  32783904  dannemann_only      rs12530
# 1307          22  50357625  dannemann_only  rs117325373
# 1308          22  50722408  dannemann_only   rs79966207
# 1309          22  50722408  dannemann_only   rs79966207
# 1310          22  50722408  dannemann_only   rs79966207
#
#                                           DISEASE/TRAIT  \
# 0                              Lung function (FEV1/FVC)
# 1                                          Visceral fat
# 2                                          Visceral fat
# 3                Systemic juvenile idiopathic arthritis
# 4                                                Height
# ...                                                 ...
# 1306                                  IgG glycosylation
# 1307  Response to paliperidone in schizophrenia (pos...
# 1308                   Blond vs. brown/black hair color
# 1309                                    Body mass index
# 1310                                         Hair color
#
#                     REPORTED GENE(S)          MAPPED_GENE  \
# 0                                NaN                MEGF6
# 1     TP73, CCDC27, KIAA0495, LRRC47                 TP73
# 2     TP73, CCDC27, KIAA0495, LRRC47                 TP73
# 3                   LOC284661, AJAP1  EEF1DP6 - LINC01777
# 4                SPSB1, LOC100506022   SPSB1 - BX323043.1
# ...                              ...                  ...
# 1306                              NR                 RTCB
# 1307                             NaN                 PIM3
# 1308                          PLXNB2               PLXNB2
# 1309                              NR               PLXNB2
# 1310                             NaN               PLXNB2
#
#      STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 0                   rs947350-?                    NR   1E-34         NaN
# 1                 rs10910018-A                  0.04    2E-6         NaN
# 2                 rs10910018-A                  0.04    2E-6         NaN
# 3                 rs72632736-?                   NaN    3E-9    2.400000
# 4                rs118100927-?                    NR   9E-12    0.034456
# ...                        ...                   ...     ...         ...
# 1306                 rs12530-C      0.18432396929239    3E-6    0.182800
# 1307             rs117325373-G                    NR    2E-6    6.346900
# 1308              rs79966207-C                0.1776   5E-10    1.063000
# 1309              rs79966207-?                    NR    6E-9         NaN
# 1310              rs79966207-?                    NR   3E-12         NaN
#
#                     95% CI (TEXT)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                     [1.80-3.30]
# 4     [0.025-0.044] unit increase
# ...                           ...
# 1306    [0.11-0.26] unit increase
# 1307           [NR] unit decrease
# 1308                           NR
# 1309                          NaN
# 1310                          NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 0                                         FEV/FEC ratio      GCST007080
# 1                   visceral adipose tissue measurement      GCST001525
# 2                   visceral adipose tissue measurement      GCST001525
# 3                systemic juvenile idiopathic arthritis      GCST004025
# 4                                           body height      GCST008839
# ...                                                 ...             ...
# 1306                serum IgG glycosylation measurement      GCST001848
# 1307  schizophrenia, response to paliperidone, schiz...      GCST004040
# 1308                                         hair color      GCST006988
# 1309                                    body mass index      GCST009871
# 1310                            hair colour measurement      GCST007082
#
# [1311 rows x 14 columns]

# %% [markdown]
# ## Immune-related diseases associated with Neanderthal SNPs

# %% [markdown]
# ### Infections

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('influenza')]
# Out:
#      Chromosome   Position          Source         ID  \
# 700           3  191695113  dannemann_only  rs4261353
#
#                            DISEASE/TRAIT REPORTED GENE(S)  \
# 700  Severe influenza A (H1N1) infection            FGF12
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 700  AC026320.2 - AC026320.1               rs4261353-?              0.001866
#
#     P-VALUE  OR or BETA  95% CI (TEXT)        MAPPED_TRAIT STUDY ACCESSION
# 700    1E-8       27.44  [4.948-152.1]  influenza A (H1N1)      GCST003123

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('influenza')]
# Out:
#      Chromosome   Position          Source         ID  \
# 700           3  191695113  dannemann_only  rs4261353
#
#                            DISEASE/TRAIT REPORTED GENE(S)  \
# 700  Severe influenza A (H1N1) infection            FGF12
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 700  AC026320.2 - AC026320.1               rs4261353-?              0.001866
#
#     P-VALUE  OR or BETA  95% CI (TEXT)        MAPPED_TRAIT STUDY ACCESSION
# 700    1E-8       27.44  [4.948-152.1]  influenza A (H1N1)      GCST003123

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('HIV')]
# Out:
#      Chromosome   Position          Source          ID  \
# 377           4  161506897            both  rs17291045
# 483           9   83282271    simonti_only  rs72749479
# 484           9   83285174    simonti_only  rs72749483
# 827           6  117753834  dannemann_only  rs36111427
# 976          10   44524675  dannemann_only  rs17154929
#
#                                          DISEASE/TRAIT REPORTED GENE(S)  \
# 377                                      HIV-1 control       intergenic
# 483  Time-dependent creatinine clearance change res...               NR
# 484  Time-dependent creatinine clearance change res...               NR
# 827  Time-dependent creatinine clearance change res...               NR
# 976                            HIV-associated dementia       intergenic
#
#                 MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 377               LINC02477              rs17291045-?                    NR
# 483       MTND2P9 - RPS19P6              rs72749479-?                   NaN
# 484       MTND2P9 - RPS19P6              rs72749483-?                   NaN
# 827              AL132671.2              rs36111427-?                   NaN
# 976  LINC00841 - AL137026.2              rs17154929-T                    NR
#
#     P-VALUE  OR or BETA 95% CI (TEXT)  \
# 377    5E-8         NaN           NaN
# 483    7E-7         NaN           NaN
# 484    7E-7         NaN           NaN
# 827    9E-6         NaN           NaN
# 976    1E-7         NaN           NaN
#
#                                           MAPPED_TRAIT STUDY ACCESSION
# 377                                    HIV-1 infection      GCST000549
# 483  response to tenofovir, HIV infection, creatini...      GCST006069
# 484  response to tenofovir, HIV infection, creatini...      GCST006069
# 827  response to tenofovir, HIV infection, creatini...      GCST006069
# 976                                      AIDS dementia      GCST001542

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('Malaria')]
# Out:
#     Chromosome  Position        Source          ID DISEASE/TRAIT  \
# 70          11   4790575  simonti_only  rs12788102       Malaria
#
#    REPORTED GENE(S)    MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 70              HBB  OR51F1, MMP26              rs12788102-A
#
#    RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT) MAPPED_TRAIT  \
# 70                    NR   2E-16        2.15   [1.79-2.59]      malaria
#
#    STUDY ACCESSION
# 70      GCST002033

# %% [markdown]
# ### Allergic diseases

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('aller')]
# Out:
#      Chromosome   Position          Source           ID  \
# 143          12   48196982    simonti_only   rs55726902
# 341           3  196373582    simonti_only    rs4916533
# 342           3  196373582    simonti_only    rs4916533
# 344           4   38811051    simonti_only   rs11727978
# 345           4   38819403    simonti_only   rs66819621
# 701           3  196343817  dannemann_only  rs113048054
# 729           4  123141070  dannemann_only   rs45613035
#
#                                       DISEASE/TRAIT REPORTED GENE(S)  \
# 143  Allergic disease (asthma, hay fever or eczema)            HDAC7
# 341         Asthma or allergic disease (pleiotropy)            NRROS
# 342                         Hay fever and/or eczema               NR
# 344                                         Allergy       TLR1, TLR6
# 345                               Allergic rhinitis             TLR1
# 701  Allergic disease (asthma, hay fever or eczema)               NR
# 729                         Hay fever and/or eczema               NR
#
#                 MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 143                   HDAC7              rs55726902-G                   0.8
# 341             NRROS, PIGX               rs4916533-?                    NR
# 342             NRROS, PIGX               rs4916533-C               0.91931
# 344                    TLR1              rs11727978-?                    NR
# 345                    TLR1              rs66819621-A                0.8428
# 701  AC092933.2 - LINC01063             rs113048054-A               0.93413
# 729                KIAA1109              rs45613035-C               0.09838
#
#     P-VALUE  OR or BETA  95% CI (TEXT)                       MAPPED_TRAIT  \
# 143   3E-16    1.051000    [1.04-1.06]                            allergy
# 341    2E-8    1.075269            NaN                    allergy, asthma
# 342   6E-10    1.070778    [1.05-1.09]          Eczema, allergic rhinitis
# 344   1E-15    1.083000  [1.062-1.104]                            allergy
# 345   2E-25    1.179941    [1.15-1.22]                  allergic rhinitis
# 701   4E-12    1.080497     [1.06-1.1]  Eczema, allergic rhinitis, asthma
# 729   6E-20    1.094000  [1.074-1.115]          Eczema, allergic rhinitis
#
#     STUDY ACCESSION
# 143      GCST005038
# 341      GCST007564
# 342      GCST009717
# 344      GCST003990
# 345      GCST009719
# 701      GCST009716
# 729      GCST009717

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('asthma')]
# Out:
#       Chromosome   Position          Source           ID  \
# 67            10  119647256    simonti_only   rs17642749
# 291           21   36453837            both    rs2242900
# 341            3  196373582    simonti_only    rs4916533
# 369            4  123359569            both   rs62322662
# 370            4  123359569            both   rs62322662
# 701            3  196343817  dannemann_only  rs113048054
# 702            3  196343817  dannemann_only  rs113048054
# 703            3  196349004  dannemann_only  rs112336433
# 728            4  123141070  dannemann_only   rs45613035
# 730            4  123141070  dannemann_only   rs45613035
# 731            4  123141070  dannemann_only   rs45613035
# 732            4  123141070  dannemann_only   rs45613035
# 733            4  123141070  dannemann_only   rs45613035
# 895            8   76319166  dannemann_only  rs117628011
# 970           10    6115639  dannemann_only   rs62626322
# 971           10    6115639  dannemann_only   rs62626322
# 1274          20    3827309  dannemann_only    rs4815617
#
#                                        DISEASE/TRAIT  \
# 67                          Asthma (sex interaction)
# 291                                           Asthma
# 341          Asthma or allergic disease (pleiotropy)
# 369                                           Asthma
# 370                             Asthma (adult onset)
# 701   Allergic disease (asthma, hay fever or eczema)
# 702                                           Asthma
# 703                                           Asthma
# 728                         Asthma (childhood onset)
# 730                                           Asthma
# 731                                    Atopic asthma
# 732                                           Asthma
# 733                                           Asthma
# 895                      Diisocyanate-induced asthma
# 970                                           Asthma
# 971                                           Asthma
# 1274                                          Asthma
#
#                              REPORTED GENE(S)             MAPPED_GENE  \
# 67                                  RAB11FIP2  AL513324.1 - RAB11FIP2
# 291                                     RUNX1                   RUNX1
# 341                                     NRROS             NRROS, PIGX
# 369                                ADAD1, IL2             ADAD1 - IL2
# 370                                ADAD1, IL2             ADAD1 - IL2
# 701                                        NR  AC092933.2 - LINC01063
# 702                             NNROS, LRRC33  AC092933.2 - LINC01063
# 703                                     NRROS  AC092933.2 - LINC01063
# 728                                        NR                KIAA1109
# 730      ADAD1, IL2, IL21, IL21-AS1, KIAA1109                KIAA1109
# 731                                        NR                KIAA1109
# 732                                  KIAA1109                KIAA1109
# 733   KIAA1109, ADAD1, IL2, TRPC3, BBS7, IL21                KIAA1109
# 895                                intergenic           PKMP4 - HNF4G
# 970                                        NR        RPL32P23 - RBM17
# 971                                     RBM17        RPL32P23 - RBM17
# 1274                                 KIAA1271            AP5S1 - MAVS
#
#      STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 67                rs17642749-G                 0.086    4E-7    2.970000
# 291                rs2242900-G                  0.14   2E-18         NaN
# 341                rs4916533-?                    NR    2E-8    1.075269
# 369               rs62322662-G                    NR   2E-18    1.119000
# 370               rs62322662-?                    NR   8E-10    1.084000
# 701              rs113048054-A               0.93413   4E-12    1.080497
# 702              rs113048054-G               0.06587   3E-11         NaN
# 703              rs112336433-C               0.93272    3E-8    1.069407
# 728               rs45613035-?                    NR   9E-12         NaN
# 730               rs45613035-C              0.098644   1E-12    1.077323
# 731               rs45613035-?                    NR   5E-16         NaN
# 732               rs45613035-C                    NR   6E-19    1.107000
# 733               rs45613035-C               0.09872   5E-14    1.081750
# 895              rs117628011-A                 0.054    5E-6    3.060000
# 970               rs62626322-?                    NR    3E-9         NaN
# 971               rs62626322-G              0.112377    4E-8    1.055875
# 1274               rs4815617-?                    NR    8E-6         NaN
#
#      95% CI (TEXT)                         MAPPED_TRAIT STUDY ACCESSION
# 67     [1.90-4.63]  sex interaction measurement, asthma      GCST002445
# 291            NaN                               asthma      GCST010043
# 341            NaN                      allergy, asthma      GCST007564
# 369    [1.09-1.14]                               asthma      GCST007798
# 370    [1.06-1.11]                   adult onset asthma      GCST007799
# 701     [1.06-1.1]    Eczema, allergic rhinitis, asthma      GCST009716
# 702            NaN                               asthma      GCST009720
# 703    [1.05-1.09]                               asthma      GCST008916
# 728            NaN               childhood onset asthma      GCST009841
# 730     [1.06-1.1]                               asthma      GCST008916
# 731            NaN                        atopic asthma      GCST009850
# 732    [1.09-1.13]                               asthma      GCST007798
# 733    [1.06-1.10]                               asthma      GCST009798
# 895    [1.85-5.04]     response to diisocyanate, asthma      GCST002875
# 970            NaN                               asthma      GCST009720
# 971    [1.04-1.08]                               asthma      GCST008916
# 1274           NaN                               asthma      GCST000576

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Eczema')]
# Out:
#       Chromosome   Position          Source           ID  \
# 342            3  196373582    simonti_only    rs4916533
# 701            3  196343817  dannemann_only  rs113048054
# 704            3  196368501  dannemann_only   rs12152276
# 729            4  123141070  dannemann_only   rs45613035
# 734            4  123141070  dannemann_only   rs45613035
# 1296          21   36457506  dannemann_only   rs73203093
#
#                                        DISEASE/TRAIT REPORTED GENE(S)  \
# 342                          Hay fever and/or eczema               NR
# 701   Allergic disease (asthma, hay fever or eczema)               NR
# 704                                           Eczema              NaN
# 729                          Hay fever and/or eczema               NR
# 734                                           Eczema              NaN
# 1296                                          Eczema              NaN
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 342              NRROS, PIGX               rs4916533-C               0.91931
# 701   AC092933.2 - LINC01063             rs113048054-A               0.93413
# 704              PIGX, NRROS              rs12152276-?                    NR
# 729                 KIAA1109              rs45613035-C               0.09838
# 734                 KIAA1109              rs45613035-?                    NR
# 1296                   RUNX1              rs73203093-?                    NR
#
#      P-VALUE  OR or BETA  95% CI (TEXT)                       MAPPED_TRAIT  \
# 342    6E-10    1.070778    [1.05-1.09]          Eczema, allergic rhinitis
# 701    4E-12    1.080497     [1.06-1.1]  Eczema, allergic rhinitis, asthma
# 704    7E-10         NaN            NaN                             Eczema
# 729    6E-20    1.094000  [1.074-1.115]          Eczema, allergic rhinitis
# 734    2E-26         NaN            NaN                             Eczema
# 1296    7E-9         NaN            NaN                             Eczema
#
#      STUDY ACCESSION
# 342       GCST009717
# 701       GCST009716
# 704       GCST007075
# 729       GCST009717
# 734       GCST007075
# 1296      GCST007075

# %% [markdown]
# ### Autoimmune/autoinflammatory diseases

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('lupus')]
# Out:
#       Chromosome   Position          Source          ID  \
# 447            7  128695983            both  rs13239597
# 578            1  198594769  dannemann_only  rs34889541
# 579            1  198594769  dannemann_only  rs34889541
# 857            7  128585616  dannemann_only  rs35000415
# 858            7  128585616  dannemann_only  rs35000415
# 859            7  128585616  dannemann_only  rs35000415
# 861            7  128594183  dannemann_only  rs10488631
# 862            7  128594183  dannemann_only  rs10488631
# 866            7  128594183  dannemann_only  rs10488631
# 873            7  128594183  dannemann_only  rs10488631
# 882            7  128616582  dannemann_only  rs12706861
# 1119          12  129294333  dannemann_only  rs11059927
# 1120          12  129300694  dannemann_only   rs1385374
# 1121          12  129300694  dannemann_only   rs1385374
# 1207          17   37885383  dannemann_only   rs4252665
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 447   Systemic lupus erythematosus and Systemic scle...      TNPO3, IRF5
# 578                        Systemic lupus erythematosus      PTPRC, CD45
# 579                        Systemic lupus erythematosus      PTPRC, CD45
# 857                        Systemic lupus erythematosus             IRF5
# 858                        Systemic lupus erythematosus             IRF5
# 859                        Systemic lupus erythematosus      IRF5, TNPO3
# 861                        Systemic lupus erythematosus             IRF5
# 862                        Systemic lupus erythematosus      TNPO3, IRF5
# 866                        Systemic lupus erythematosus            TNPO3
# 873                        Systemic lupus erythematosus      IRF5, TNPO3
# 882                        Systemic lupus erythematosus      IRF5, TNPO3
# 1119                       Systemic lupus erythematosus          SLC15A4
# 1120                       Systemic lupus erythematosus          SLC15A4
# 1121                       Systemic lupus erythematosus          SLC15A4
# 1207                       Systemic lupus erythematosus     ERBB2, MIEN1
#
#              MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 447               TPI1P2              rs13239597-?                    NR
# 578   AL157402.1 - PTPRC              rs34889541-G                  0.86
# 579   AL157402.1 - PTPRC              rs34889541-G                  0.93
# 857                 IRF5              rs35000415-?                 0.108
# 858                 IRF5              rs35000415-T                   NaN
# 859                 IRF5              rs35000415-T                    NR
# 861   AC025594.2 - TNPO3              rs10488631-C                  0.11
# 862   AC025594.2 - TNPO3              rs10488631-C                  0.12
# 866   AC025594.2 - TNPO3              rs10488631-C                  0.11
# 873   AC025594.2 - TNPO3              rs10488631-C                   NaN
# 882                TNPO3              rs12706861-T                 0.118
# 1119             SLC15A4              rs11059927-C                 0.104
# 1120             SLC15A4               rs1385374-A                  0.20
# 1121             SLC15A4               rs1385374-A                  0.17
# 1207        ERBB2, MIEN1               rs4252665-A                    NR
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 447    1E-29    1.664000          [NR]
# 578    3E-10    1.282051   [1.19-1.39]
# 579    2E-12    1.234568   [1.16-1.32]
# 857    2E-45    1.800000          [NR]
# 858    1E-60    1.830000          [NR]
# 859    1E-99    1.820000   [1.69-1.96]
# 861    7E-18    1.920000   [1.66-2.22]
# 862    2E-11         NaN           NaN
# 866    2E-13    1.829000  [1.684-1.99]
# 873   9E-110    1.920000   [1.81–2.03]
# 882    4E-71    1.760000   [1.65-1.87]
# 1119    2E-8    1.210000   [1.13-1.30]
# 1120   2E-11    1.260000   [1.18-1.35]
# 1121    8E-8    1.410000           NaN
# 1207   2E-12    1.460000   [1.26-1.70]
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 447   systemic scleroderma, systemic lupus erythemat...      GCST002069
# 578                        systemic lupus erythematosus      GCST003622
# 579                        systemic lupus erythematosus      GCST003622
# 857                        systemic lupus erythematosus      GCST003622
# 858                        systemic lupus erythematosus      GCST003156
# 859                        systemic lupus erythematosus      GCST005752
# 861                        systemic lupus erythematosus      GCST000996
# 862                        systemic lupus erythematosus      GCST000144
# 866                        systemic lupus erythematosus      GCST002463
# 873                        systemic lupus erythematosus      GCST003155
# 882                        systemic lupus erythematosus      GCST007400
# 1119                       systemic lupus erythematosus      GCST007400
# 1120                       systemic lupus erythematosus      GCST000507
# 1121                       systemic lupus erythematosus      GCST001795
# 1207                       systemic lupus erythematosus      GCST005752

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('rheumatoid')]
# Out:
#       Chromosome   Position          Source          ID         DISEASE/TRAIT  \
# 452            7  129962414    simonti_only   rs2306848  Rheumatoid arthritis
# 871            7  128594183  dannemann_only  rs10488631  Rheumatoid arthritis
# 1148          14   61940675  dannemann_only   rs3783782  Rheumatoid arthritis
# 1149          14   61940675  dannemann_only   rs3783782  Rheumatoid arthritis
# 1150          14   61940675  dannemann_only   rs3783782  Rheumatoid arthritis
# 1151          14   61940675  dannemann_only   rs3783782  Rheumatoid arthritis
#
#      REPORTED GENE(S)         MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 452              CPA4                CPA4               rs2306848-G
# 871              IRF5  AC025594.2 - TNPO3              rs10488631-C
# 1148            PRKCH               PRKCH               rs3783782-A
# 1149            PRKCH               PRKCH               rs3783782-A
# 1150            PRKCH               PRKCH               rs3783782-A
# 1151            PRKCH               PRKCH               rs3783782-A
#
#      RISK ALLELE FREQUENCY P-VALUE  OR or BETA                95% CI (TEXT)  \
# 452                  0.948   6E-12         NaN                          NaN
# 871                   0.11   4E-11    1.190000                         [NR]
# 1148                  0.09    2E-9    1.140000                  [1.09-1.18]
# 1149                  0.22    4E-9    1.140000                  [1.09-1.19]
# 1150                    NR    1E-7    0.151127  [0.095-0.207] unit increase
# 1151                  0.23    1E-7    0.160620     [0.1-0.22] unit increase
#
#               MAPPED_TRAIT STUDY ACCESSION
# 452   rheumatoid arthritis      GCST007843
# 871   rheumatoid arthritis      GCST000679
# 1148  rheumatoid arthritis      GCST002318
# 1149  rheumatoid arthritis      GCST002318
# 1150  rheumatoid arthritis      GCST006959
# 1151  rheumatoid arthritis      GCST006959

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('scleroderma')]
# Out:
#      Chromosome   Position          Source          ID  \
# 446           7  128684316    simonti_only  rs62478615
# 447           7  128695983            both  rs13239597
# 448           7  128695983            both  rs13239597
# 449           7  128708797    simonti_only  rs17340351
# 450           7  128708797    simonti_only  rs17340351
# 451           7  128708797    simonti_only  rs17340351
# 863           7  128594183  dannemann_only  rs10488631
# 865           7  128594183  dannemann_only  rs10488631
# 867           7  128594183  dannemann_only  rs10488631
# 868           7  128594183  dannemann_only  rs10488631
# 869           7  128594183  dannemann_only  rs10488631
# 870           7  128594183  dannemann_only  rs10488631
# 874           7  128594183  dannemann_only  rs10488631
# 875           7  128594183  dannemann_only  rs10488631
# 876           7  128594183  dannemann_only  rs10488631
# 877           7  128594183  dannemann_only  rs10488631
# 878           7  128594183  dannemann_only  rs10488631
# 879           7  128594183  dannemann_only  rs10488631
# 881           7  128594183  dannemann_only  rs10488631
# 883           7  128624073  dannemann_only  rs12534421
# 884           7  128624073  dannemann_only  rs12534421
# 885           7  128651522  dannemann_only  rs36073657
#
#                                          DISEASE/TRAIT REPORTED GENE(S)  \
# 446                                 Systemic sclerosis             IRF5
# 447  Systemic lupus erythematosus and Systemic scle...      TNPO3, IRF5
# 448             Limited cutaneous systemic scleroderma            TNPO3
# 449                                 Systemic sclerosis            TNPO3
# 450               Diffuse cutaneous systemic sclerosis            TNPO3
# 451   Systemic sclerosis (anti-topoisomerase-positive)            TNPO3
# 863                                 Systemic sclerosis       TNPO, IRF5
# 865                                 Systemic sclerosis      TNPO3, IRF5
# 867                                 Systemic sclerosis             IRF5
# 868                                 Systemic sclerosis             IRF5
# 869                                 Systemic sclerosis             IRF5
# 870                                 Systemic sclerosis             IRF5
# 874               Diffuse cutaneous systemic sclerosis            TNPO3
# 875      Systemic sclerosis (anti-centromere-positive)      IRF5, TNPO3
# 876   Systemic sclerosis (anti-topoisomerase-positive)            TNPO3
# 877             Limited cutaneous systemic scleroderma      TNPO3, IRF5
# 878             Limited cutaneous systemic scleroderma             IRF5
# 879               Diffuse cutaneous systemic sclerosis             IRF5
# 881                                 Systemic sclerosis      IRF5, TNPO4
# 883               Diffuse cutaneous systemic sclerosis             IRF5
# 884                                 Systemic sclerosis             IRF5
# 885                                 Systemic sclerosis      IRF5, TNPO3
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 446                    TNPO3              rs62478615-?                   NaN
# 447                   TPI1P2              rs13239597-?                    NR
# 448                   TPI1P2              rs13239597-?                    NR
# 449  AC018639.1 - AC011005.2              rs17340351-?                    NR
# 450  AC018639.1 - AC011005.2              rs17340351-?                    NR
# 451  AC018639.1 - AC011005.2              rs17340351-?                    NR
# 863       AC025594.2 - TNPO3              rs10488631-C                    NR
# 865       AC025594.2 - TNPO3              rs10488631-C                  0.09
# 867       AC025594.2 - TNPO3              rs10488631-?                    NR
# 868       AC025594.2 - TNPO3              rs10488631-?                    NR
# 869       AC025594.2 - TNPO3              rs10488631-?                    NR
# 870       AC025594.2 - TNPO3              rs10488631-?                    NR
# 874       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 875       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 876       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 877       AC025594.2 - TNPO3              rs10488631-?                    NR
# 878       AC025594.2 - TNPO3              rs10488631-?                    NR
# 879       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 881       AC025594.2 - TNPO3              rs10488631-C                    NR
# 883                    TNPO3              rs12534421-?                    NR
# 884                    TNPO3              rs12534421-?                    NR
# 885                    TNPO3              rs36073657-T                   0.1
#
#     P-VALUE  OR or BETA 95% CI (TEXT)  \
# 446   1E-10       1.530           NaN
# 447   1E-29       1.664          [NR]
# 448    9E-7         NaN           NaN
# 449   2E-10         NaN           NaN
# 450    7E-7         NaN           NaN
# 451    1E-8         NaN           NaN
# 863   2E-13       1.500   [1.35-1.67]
# 865    4E-7       1.350   [1.20-1.51]
# 867   2E-10       1.500   [1.32-1.69]
# 868    8E-7       1.630   [1.34-1.98]
# 869    1E-9       1.610   [1.38-1.88]
# 870    2E-7       1.520   [1.30-1.79]
# 874    1E-9         NaN           NaN
# 875    9E-7         NaN           NaN
# 876    4E-7         NaN           NaN
# 877   3E-10         NaN           NaN
# 878    9E-7         NaN           NaN
# 879    1E-9         NaN           NaN
# 881    6E-7       1.630   [1.34-1.97]
# 883    4E-6         NaN           NaN
# 884   7E-10         NaN           NaN
# 885   3E-21       1.400           NaN
#
#                                           MAPPED_TRAIT STUDY ACCESSION
# 446                               systemic scleroderma      GCST005534
# 447  systemic scleroderma, systemic lupus erythemat...      GCST002069
# 448                                limited scleroderma      GCST005555
# 449                               systemic scleroderma      GCST005554
# 450                                diffuse scleroderma      GCST005553
# 451  anti-topoisomerase-I-antibody-positive systemi...      GCST005551
# 863                               systemic scleroderma      GCST000650
# 865                               systemic scleroderma      GCST001146
# 867                               systemic scleroderma      GCST001160
# 868                               systemic scleroderma      GCST001156
# 869                               systemic scleroderma      GCST001156
# 870                               systemic scleroderma      GCST001156
# 874                                diffuse scleroderma      GCST005335
# 875  anti-centromere-antibody-positive systemic scl...      GCST005333
# 876  anti-topoisomerase-I-antibody-positive systemi...      GCST005332
# 877                                limited scleroderma      GCST005334
# 878                                limited scleroderma      GCST005555
# 879                                diffuse scleroderma      GCST005335
# 881                               systemic scleroderma      GCST006493
# 883                                diffuse scleroderma      GCST005553
# 884                               systemic scleroderma      GCST005554
# 885                               systemic scleroderma      GCST009131

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Sjogren')]
# Out:
#      Chromosome   Position Source          ID       DISEASE/TRAIT  \
# 445           7  128681062   both  rs17339836  Sjögren's syndrome
#
#     REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 445      IRF5, TNPO3       TNPO3              rs17339836-T
#
#     RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)      MAPPED_TRAIT  \
# 445                  0.12   2E-16        1.58   [1.36–1.84]  Sjogren syndrome
#
#     STUDY ACCESSION
# 445      GCST004878

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Grave')]
# Out:
#      Chromosome   Position          Source         ID    DISEASE/TRAIT  \
# 548           1  160464911  dannemann_only  rs1265883  Graves' disease
#
#     REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 548           SLAMF6      SLAMF6               rs1265883-C
#
#     RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)    MAPPED_TRAIT  \
# 548                   0.1   2E-18        1.34   [1.25-1.43]  Graves disease
#
#     STUDY ACCESSION
# 548      GCST001984

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('glomerulonephritis')]
# Out:
#      Chromosome   Position        Source          ID  \
# 255           2  160878364  simonti_only  rs17830558
# 258           2  160914156  simonti_only  rs17831251
# 259           2  160914156  simonti_only  rs17831251
# 260           2  160914156  simonti_only  rs17831251
# 261           2  160917497  simonti_only   rs4664308
#
#                          DISEASE/TRAIT            REPORTED GENE(S)  \
# 255             Membranous nephropathy                      PLA2R1
# 258             Membranous nephropathy                      PLA2R1
# 259             Membranous nephropathy                      PLA2R1
# 260             Membranous nephropathy                      PLA2R1
# 261  Idiopathic membranous nephropathy  LY75, ITGB6, PLA2R1, RBMS1
#
#     MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  \
# 255      PLA2R1              rs17830558-T                  0.52   4E-10
# 258      PLA2R1              rs17831251-C                    NR  5E-103
# 259      PLA2R1              rs17831251-C                  0.61   5E-48
# 260      PLA2R1              rs17831251-C                   0.7   4E-61
# 261      PLA2R1               rs4664308-A                  0.43   9E-29
#
#      OR or BETA 95% CI (TEXT)                   MAPPED_TRAIT STUDY ACCESSION
# 255        1.87   [1.54–2.28]  membranous glomerulonephritis      GCST003402
# 258        2.25   [2.09-2.42]  membranous glomerulonephritis      GCST010004
# 259        1.98   [1.81-2.17]  membranous glomerulonephritis      GCST010005
# 260        2.81   [2.48-3.17]  membranous glomerulonephritis      GCST010006
# 261        2.28   [1.96-2.64]  membranous glomerulonephritis      GCST000984

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('colitis')]
# Out:
#       Chromosome  Position          Source          ID  \
# 139           12  40528432            both  rs12422544
# 1162          14  75741751  dannemann_only   rs1569328
# 1223          18  77220616  dannemann_only   rs7236492
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 139                                  Ulcerative colitis               NR
# 1162  Chronic inflammatory diseases (ankylosing spon...              FOS
# 1223  Chronic inflammatory diseases (ankylosing spon...           NFATC1
#
#               MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 139   SLC2A13 - LINC02555              rs12422544-G               0.01915
# 1162     AF111167.1 - FOS               rs1569328-?                    NR
# 1223   AC018445.5, NFATC1               rs7236492-?                    NR
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 139     3E-6    1.215345    [1.13-1.3]
# 1162    2E-9         NaN           NaN
# 1223    1E-7         NaN           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 139                                  ulcerative colitis      GCST003045
# 1162  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537
# 1223  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Crohn')]
# Out:
#       Chromosome  Position          Source          ID  \
# 140           12  40528432            both  rs12422544
# 978           10  64415184  dannemann_only   rs7076156
# 1099          12  40601940  dannemann_only  rs11175593
# 1128          13  40833012  dannemann_only  rs17061048
# 1160          14  75741751  dannemann_only   rs1569328
# 1162          14  75741751  dannemann_only   rs1569328
# 1163          14  75741751  dannemann_only   rs1569328
# 1221          18  77220616  dannemann_only   rs7236492
# 1223          18  77220616  dannemann_only   rs7236492
#
#                                           DISEASE/TRAIT    REPORTED GENE(S)  \
# 140                                     Crohn's disease                  NR
# 978                                     Crohn's disease   ADO, ZNF365, ERG2
# 1099                                    Crohn's disease        MUC19, LRRK2
# 1128                                    Crohn's disease                  NR
# 1160                                    Crohn's disease                  NR
# 1162  Chronic inflammatory diseases (ankylosing spon...                 FOS
# 1163                                    Crohn's disease  FOS, RP11-293M10.1
# 1221                                    Crohn's disease         NFATC1, TST
# 1223  Chronic inflammatory diseases (ankylosing spon...              NFATC1
#
#                      MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 140          SLC2A13 - LINC02555              rs12422544-G
# 978       AC067752.1, AC024598.1               rs7076156-G
# 1099  LRRK2-DT, LRRK2, LINC02471              rs11175593-T
# 1128                   LINC00598              rs17061048-A
# 1160            AF111167.1 - FOS               rs1569328-G
# 1162            AF111167.1 - FOS               rs1569328-?
# 1163            AF111167.1 - FOS               rs1569328-?
# 1221          AC018445.5, NFATC1               rs7236492-G
# 1223          AC018445.5, NFATC1               rs7236492-?
#
#      RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)  \
# 140                0.01915   4E-25    1.455191   [1.38-1.53]
# 978                  0.751    7E-9    1.190000   [1.10-1.30]
# 1099                  0.02   3E-10    1.540000          [NR]
# 1128                  0.95    1E-7    1.161814   [1.11-1.22]
# 1160                  0.83   6E-11    1.115402   [1.08-1.15]
# 1162                    NR    2E-9         NaN           NaN
# 1163                   NaN    1E-7         NaN           NaN
# 1221                  0.85    9E-9    1.104796   [1.07-1.14]
# 1223                    NR    1E-7         NaN           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 140                                     Crohn's disease      GCST003044
# 978                                     Crohn's disease      GCST001438
# 1099                                    Crohn's disease      GCST000207
# 1128                                    Crohn's disease      GCST003044
# 1160                                    Crohn's disease      GCST003044
# 1162  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537
# 1163                                    Crohn's disease      GCST004132
# 1221                                    Crohn's disease      GCST003044
# 1223  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('bowel')]
# Out:
#       Chromosome  Position          Source          ID  \
# 301            3   2076967    simonti_only   rs4437130
# 1129          13  40833012  dannemann_only  rs17061048
# 1161          14  75741751  dannemann_only   rs1569328
# 1222          18  77220616  dannemann_only   rs7236492
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 301   Thiopurine-induced pancreatitis in inflammator...            CNTN4
# 1129                         Inflammatory bowel disease               NR
# 1161                         Inflammatory bowel disease               NR
# 1222                         Inflammatory bowel disease      NFATC1, TST
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 301   AC018814.1 - RN7SKP144               rs4437130-?                    NR
# 1129               LINC00598              rs17061048-A                  0.95
# 1161        AF111167.1 - FOS               rs1569328-G                  0.83
# 1222      AC018445.5, NFATC1               rs7236492-G                  0.85
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 301     2E-7    6.800000    [3.3-14.1]
# 1129    5E-9    1.145133           NaN
# 1161    3E-9    1.084341           NaN
# 1222    1E-8    1.083568           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 301   pancreatitis, response to thiopurine, inflamma...      GCST006208
# 1129                         inflammatory bowel disease      GCST003043
# 1161                         inflammatory bowel disease      GCST003043
# 1222                         inflammatory bowel disease      GCST003043

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('psoriasis')]
# Out:
#       Chromosome   Position          Source          ID  \
# 148           12   56750204            both   rs2066819
# 149           12   56750204            both   rs2066819
# 398            5  168386089            both  rs12188351
# 979           10   64538279  dannemann_only   rs7922314
# 1104          12   56740682  dannemann_only   rs2066807
# 1105          12   56740682  dannemann_only   rs2066807
# 1162          14   75741751  dannemann_only   rs1569328
# 1223          18   77220616  dannemann_only   rs7236492
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 148                                  Psoriasis vulgaris     STAT2, IL23A
# 149                                           Psoriasis     STAT2, IL23A
# 398                           Inflammatory skin disease            SLIT3
# 979                                 Cutaneous psoriasis              ADO
# 1104                                          Psoriasis     IL23A, STAT2
# 1105                                          Psoriasis     IL23A, STAT2
# 1162  Chronic inflammatory diseases (ankylosing spon...              FOS
# 1223  Chronic inflammatory diseases (ankylosing spon...           NFATC1
#
#              MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 148                STAT2               rs2066819-C                    NR
# 149                STAT2               rs2066819-C                 0.934
# 398                SLIT3              rs12188351-?                    NR
# 979           AC067751.1               rs7922314-C                0.9206
# 1104               STAT2               rs2066807-G              0.932351
# 1105               STAT2               rs2066807-G              0.932351
# 1162    AF111167.1 - FOS               rs1569328-?                    NR
# 1223  AC018445.5, NFATC1               rs7236492-?                    NR
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 148    4E-15       1.419            NR
# 149    5E-17       1.390           NaN
# 398     1E-8         NaN           NaN
# 979     2E-6       1.330            NR
# 1104   1E-10       1.550   [1.35-1.77]
# 1105   5E-12       1.400   [1.27-1.54]
# 1162    2E-9         NaN           NaN
# 1223    1E-7         NaN           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 148                                  psoriasis vulgaris      GCST003268
# 149                                           psoriasis      GCST005527
# 398                                           psoriasis      GCST002740
# 979          cutaneous psoriasis measurement, psoriasis      GCST003269
# 1104                                          psoriasis      GCST002874
# 1105                                          psoriasis      GCST002874
# 1162  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537
# 1223  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('celiac')]
# Out:
#      Chromosome   Position          Source          ID   DISEASE/TRAIT  \
# 318           3   46235201            both  rs13098911  Celiac disease
# 735           4  123261530  dannemann_only  rs62321692  Celiac disease
#
#                         REPORTED GENE(S) MAPPED_GENE  \
# 318  CCRL2, CCR5, CCR9, CCR1, CCR2, CCR3        CCR3
# 735                             KIAA1109    KIAA1109
#
#     STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 318              rs13098911-A                  0.10   3E-17      1.3000
# 735              rs62321692-?                    NR    1E-8      0.1924
#
#      95% CI (TEXT)    MAPPED_TRAIT STUDY ACCESSION
# 318    [1.23-1.39]  celiac disease      GCST000612
# 735  unit decrease  celiac disease      GCST008489

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('multiple sclerosis')]
# Out:
#      Chromosome   Position          Source          ID       DISEASE/TRAIT  \
# 829           6  138179146  dannemann_only  rs17780048  Multiple sclerosis
#
#     REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 829     LOC100130476     WAKMAR2              rs17780048-C
#
#     RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)  \
# 829                    NR   5E-12      1.1008            NR
#
#            MAPPED_TRAIT STUDY ACCESSION
# 829  multiple sclerosis      GCST009597

# %% [markdown]
# ## Do immune disease-associated Neanderthal SNPs show eQTL?

# %%
# Load eQTL data
fairfax_ori = pd.read_csv("../fairfax/tab2_a_cis_eSNPs.txt", sep="\t", usecols=["SNP", "Gene", "Min.dataset", "LPS2.FDR", "LPS24.FDR", "IFN.FDR", "Naive.FDR"])

fairfax_re = pd.read_csv('overlap_filtered_fairfax.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
fairfax_re.sort_values('pvalue', inplace=True)
fairfax_re.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

nedelec_re = pd.read_csv('overlap_filtered_nedelec.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
nedelec_re.sort_values('pvalue', inplace=True)
nedelec_re.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

quach = pd.read_csv('overlap_filtered_quach.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
quach.sort_values('pvalue', inplace=True)
quach.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

alasoo = pd.read_csv('overlap_filtered_alasoo.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
alasoo.sort_values('pvalue', inplace=True)
alasoo.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

# %%
# Selected Neanderthal SNPs with immune disease associations
gwas = open('overlapped_SNPs.txt', 'r').read().splitlines()
gwas
# Out:
# ['rs55726902',
#  'rs11727978',
#  'rs66819621',
#  'rs4916533',
#  'rs12152276',
#  'rs113048054',
#  'rs45613035',
#  'rs73203093',
#  'rs13239597',
#  'rs35000415',
#  'rs10488631',
#  'rs12706861',
#  'rs34889541',
#  'rs11059927',
#  'rs1385374',
#  'rs4252665',
#  'rs2066819',
#  'rs2066807',
#  'rs12188351',
#  'rs7922314',
#  'rs17061048',
#  'rs7236492',
#  'rs1569328',
#  'rs12422544',
#  'rs7076156',
#  'rs11175593',
#  'rs62478615',
#  'rs13239597',
#  'rs17340351',
#  'rs10488631',
#  'rs12534421',
#  'rs36073657',
#  'rs2306848',
#  'rs10488631',
#  'rs3783782',
#  'rs17830558',
#  'rs17831251',
#  'rs4664308',
#  'rs13098911',
#  'rs62321692',
#  'rs17780048',
#  'rs17339836',
#  'rs1265883',
#  'rs4261353',
#  'rs17291045',
#  'rs66659415',
#  'rs75482080',
#  'rs150469170',
#  'rs12788102',
#  'rs2660',
#  'rs2384071',
#  'rs2384072',
#  'rs2057778']

# %%
# Overlap with original Fairfax eQTLs
ls = set(list(fairfax_ori.SNP)).intersection(gwas)
fairfax_ori.loc[fairfax_ori.SNP.isin(ls)]
# Out:
#              SNP    Gene  LPS2.FDR  LPS24.FDR   IFN.FDR  Naive.FDR Min.dataset
# 5823   rs7236492  NFATC1  0.254156   0.000012  0.000213   0.002774       LPS24
# 6359   rs2066807   CNPY2  0.074123   0.000780  0.000656   0.034881         IFN
# 9990   rs7236492  NFATC1       NaN   0.000460  0.028019   0.164114       LPS24
# 12213  rs7236492  NFATC1       NaN   0.032637  0.183918   0.022086       Naive
# 12676  rs2066807   TMEM4  0.295496   0.000184  0.286362   0.046866       LPS24

# %%
# Overlap with recomputed Fairfax eQTLs
ls = set(list(fairfax_re.rsid)).intersection(gwas)
fairfax_re.loc[fairfax_re.rsid.isin(ls)]
# Out:
#              rsid         pvalue          gene_id      beta Condition
# 30222      rs2660  1.977790e-137  ENSG00000089127  1.179160     Naive
# 30214   rs2057778  9.354430e-134  ENSG00000089127  1.202460     Naive
# 7083       rs2660  7.975460e-130  ENSG00000089127  1.502870       IFN
# 7069    rs2057778  2.289550e-129  ENSG00000089127  1.538060       IFN
# 7496    rs2384072  2.502920e-111  ENSG00000089127  1.431310       IFN
# 7489    rs2384071  2.567830e-111  ENSG00000089127  1.431740       IFN
# 30454   rs2384071  4.288830e-110  ENSG00000089127  1.103850     Naive
# 30458   rs2384072  4.375000e-110  ENSG00000089127  1.103500     Naive
# 13481      rs2660   1.645210e-64  ENSG00000089127  1.252040      LPS2
# 13471   rs2057778   3.817330e-63  ENSG00000089127  1.271850      LPS2
# 13771   rs2384071   1.261840e-53  ENSG00000089127  1.163310      LPS2
# 13776   rs2384072   1.284420e-53  ENSG00000089127  1.163060      LPS2
# 7492    rs2384071   1.100960e-42  ENSG00000111331  0.430217       IFN
# 7499    rs2384072   1.117150e-42  ENSG00000111331  0.430054       IFN
# 7086       rs2660   1.106500e-37  ENSG00000111331  0.414827       IFN
# 7072    rs2057778   2.996000e-37  ENSG00000111331  0.422814       IFN
# 20297   rs2057778   3.281700e-22  ENSG00000089127  0.780804     LPS24
# 20299      rs2660   5.981310e-22  ENSG00000089127  0.757316     LPS24
# 20358   rs2384072   9.434320e-20  ENSG00000089127  0.706218     LPS24
# 20357   rs2384071   9.545250e-20  ENSG00000089127  0.706366     LPS24
# 7501    rs2384072   1.108720e-18  ENSG00000111335 -0.265493       IFN
# 7494    rs2384071   1.118460e-18  ENSG00000111335 -0.265552       IFN
# 13778   rs2384072   9.987560e-18  ENSG00000111331  0.381958      LPS2
# 13773   rs2384071   9.999430e-18  ENSG00000111331  0.382019      LPS2
# 7088       rs2660   1.494520e-17  ENSG00000111335 -0.261264       IFN
# 7074    rs2057778   3.697720e-17  ENSG00000111335 -0.264579       IFN
# 13483      rs2660   1.160290e-15  ENSG00000111331  0.366916      LPS2
# 13473   rs2057778   1.539890e-15  ENSG00000111331  0.373517      LPS2
# 10585  rs11727978   4.017890e-14  ENSG00000174125  0.266428      LPS2
# 10587  rs66819621   3.029170e-13  ENSG00000174125  0.255116      LPS2
# 24832  rs66819621   4.490050e-13  ENSG00000174125  0.148068     Naive
# 24830  rs11727978   1.211590e-12  ENSG00000174125  0.146342     Naive
# 30457   rs2384071   1.644230e-12  ENSG00000111335 -0.238254     Naive
# 30461   rs2384072   1.663820e-12  ENSG00000111335 -0.238131     Naive
# 30217   rs2057778   3.400930e-12  ENSG00000111335 -0.244055     Naive
# 30225      rs2660   5.686020e-12  ENSG00000111335 -0.235535     Naive
# 17052  rs11727978   5.642220e-11  ENSG00000174125  0.218371     LPS24
# 21872   rs7236492   9.314820e-11  ENSG00000131196  0.153990     LPS24
# 17054  rs66819621   1.268620e-10  ENSG00000174125  0.212711     LPS24
# 32063   rs7236492   1.804790e-09  ENSG00000131196  0.105722     Naive
# 29867   rs2066807   1.983580e-09  ENSG00000170581 -0.186349     Naive
# 23108   rs2066819   2.123820e-09  ENSG00000170581 -0.188547     Naive

# %%
# Overlap with recomputed Nedelec eQTLs
ls = set(list(nedelec_re.rsid)).intersection(gwas)
nedelec_re.loc[nedelec_re.rsid.isin(ls)]
# Out:
#             rsid        pvalue          gene_id      beta   Condition
# 1674   rs2384071  1.765550e-13  ENSG00000111331  0.162116  Salmonella
# 1675   rs2384072  1.767620e-13  ENSG00000111331  0.162108  Salmonella
# 1614   rs2057778  1.076100e-11  ENSG00000111331  0.157447  Salmonella
# 1616      rs2660  1.077880e-11  ENSG00000111331  0.157389  Salmonella
# 1083  rs55726902  1.083070e-11  ENSG00000061273  0.296714  Salmonella
# 121   rs55726902  1.999700e-09  ENSG00000061273  0.253493    Listeria

# %%
# Overlap with recomputed Quach eQTLs
ls = set(list(quach.rsid)).intersection(gwas)
quach.loc[quach.rsid.isin(ls)]
# Out:
#             rsid        pvalue          gene_id      beta Condition
# 916       rs2660  3.884100e-15  ENSG00000111331  0.197481       IAV
# 914    rs2057778  5.005350e-15  ENSG00000111331  0.197127       IAV
# 975    rs2384072  6.712570e-15  ENSG00000111331  0.194627       IAV
# 974    rs2384071  6.717330e-15  ENSG00000111331  0.194641       IAV
# 1017  rs11059927  4.876310e-12  ENSG00000139370 -0.264890       IAV
# 1024   rs1385374  4.880100e-12  ENSG00000139370 -0.264857       IAV
# 7240   rs2384071  4.871050e-10  ENSG00000111331  0.175183      R848
# 7241   rs2384072  4.875020e-10  ENSG00000111331  0.175165      R848
# 7182      rs2660  1.279440e-09  ENSG00000111331  0.172391      R848
# 7180   rs2057778  1.517360e-09  ENSG00000111331  0.171991      R848
# 8158  rs13098911  2.205190e-08  ENSG00000283646  0.684537     Naive

# %%
# Overlap with recomputed Alasoo eQTLs
ls = set(list(alasoo.rsid)).intersection(gwas)
alasoo.loc[alasoo.rsid.isin(ls)]
# Out:
#             rsid        pvalue          gene_id      beta        Condition
# 1124  rs13098911  5.543130e-11  ENSG00000223552 -0.816275             IFNg
# 2543  rs66819621  5.602500e-09  ENSG00000174125 -0.463299       Salmonella
# 636       rs2660  7.556660e-09  ENSG00000089127 -0.128276  IFNg+Salmonella
# 634    rs2057778  8.340050e-09  ENSG00000089127 -0.128607  IFNg+Salmonella
# 694    rs2384071  3.364780e-08  ENSG00000089127 -0.121321  IFNg+Salmonella
# 695    rs2384072  3.371730e-08  ENSG00000089127 -0.121283  IFNg+Salmonella
