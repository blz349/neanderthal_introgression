# %% [markdown]
# # Immune disease associations of Neanderthal-introgressed SNPs
#
# This code investigates if Neanderthal-introgressed SNPs (present in Chen introgressed sequences) have been associated with any immune-related diseases, including infectious diseases, allergic diseases, autoimmune diseases and autoinflammatory diseases, using data from the NHGRI-EBI GWAS Catalog.
#
# Neanderthal-introgressed SNPs from:
# 1. Dannemann M, Prufer K & Kelso J. Functional implications of Neandertal introgression in modern humans. *Genome Biol* 2017 **18**:61.
# 2. Simonti CN *et al.* The phenotypic legacy of admixture between modern humans and Neandertals. *Science* 2016 **351**:737-41.
#
# Neanderthal-introgressed sequences by Chen *et al.* from:
# * Chen L *et al.* Identifying and interpreting apparent Neanderthal ancestry in African individuals. *Cell* 2020 **180**:677-687.
#
# GWAS summary statistics from:
# * [GWAS Catalog](https://www.ebi.ac.uk/gwas/docs/file-downloads)

# %%
# Import modules
import pandas as pd

# %% [markdown]
# ## Get Neanderthal SNPs present in GWAS Catalog

# %%
# Load Chen Neanderthal-introgressed SNPs
chen = pd.read_excel('../chen/Additional File 1.xlsx', 'Sheet1', usecols=['Chromosome', 'Position', 'Source', 'ID', 'Chen'])
neanderthal = chen.loc[chen.Chen == 'Yes'].copy()
neanderthal.drop('Chen', axis=1)
# Out:
#                  ID  Chromosome  Position          Source
# 0       rs118163204           1    834360    simonti_only
# 1        rs79501908           1    838695    simonti_only
# 2       rs151325546           1    850373    simonti_only
# 3        rs80174979           1    854793    simonti_only
# 13      rs117504198           1   1964852    simonti_only
# ...             ...         ...       ...             ...
# 353190  rs373168311          22  51020584  dannemann_only
# 353191   rs62239545          22  51026458  dannemann_only
# 353192   rs58521696          22  51026842  dannemann_only
# 353193  rs138179215          22  51028027  dannemann_only
# 353194  rs146102218          22  51028231  dannemann_only
#
# [306908 rows x 4 columns]

# %%
# Load GWAS catalog
catalog = pd.read_csv('GWAS_Catalog.tsv', sep="\t", header=0,
                      usecols=['DISEASE/TRAIT', 'CHR_ID', 'CHR_POS', 'REPORTED GENE(S)', 'MAPPED_GENE',
                               'STRONGEST SNP-RISK ALLELE', 'SNPS', 'RISK ALLELE FREQUENCY', 'P-VALUE', 'OR or BETA',
                               '95% CI (TEXT)', 'MAPPED_TRAIT', 'STUDY ACCESSION'], low_memory=False)
catalog = catalog.loc[catalog.CHR_ID != 'X'].copy()
catalog = catalog.loc[catalog.CHR_ID != 'Y'].copy()
catalog.rename(columns={'CHR_ID': 'Chromosome', 'CHR_POS': 'Position', 'SNPS': 'ID'}, inplace=True)

# %%
# Neanderthal SNPs present in GWAS catalog
nean_catalog = neanderthal.merge(catalog.drop(columns=['Chromosome', 'Position']), how='inner', on='ID')
nean_catalog
# Out:
#                ID  Chromosome  Position          Source Chen  \
# 0       rs2742690           1   2987268  dannemann_only  Yes
# 1        rs947350           1   3431555            both  Yes
# 2      rs12562437           1   3651031  dannemann_only  Yes
# 3      rs10910018           1   3651409            both  Yes
# 4      rs10910018           1   3651409            both  Yes
# ...           ...         ...       ...             ...  ...
# 1133      rs12530          22  32783904  dannemann_only  Yes
# 1134  rs117325373          22  50357625  dannemann_only  Yes
# 1135   rs79966207          22  50722408  dannemann_only  Yes
# 1136   rs79966207          22  50722408  dannemann_only  Yes
# 1137   rs79966207          22  50722408  dannemann_only  Yes
#
#                                           DISEASE/TRAIT  \
# 0                                       Waist-hip ratio
# 1                              Lung function (FEV1/FVC)
# 2     Visceral adipose tissue/subcutaneous adipose t...
# 3                                          Visceral fat
# 4                                          Visceral fat
# ...                                                 ...
# 1133                                  IgG glycosylation
# 1134  Response to paliperidone in schizophrenia (pos...
# 1135                   Blond vs. brown/black hair color
# 1136                                    Body mass index
# 1137                                         Hair color
#
#                     REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 0                                NaN      PRDM16               rs2742690-A
# 1                                NaN       MEGF6                rs947350-?
# 2     TP73, CCDC27, KIAA0495, LRRC47        TP73              rs12562437-T
# 3     TP73, CCDC27, KIAA0495, LRRC47        TP73              rs10910018-A
# 4     TP73, CCDC27, KIAA0495, LRRC47        TP73              rs10910018-A
# ...                              ...         ...                       ...
# 1133                              NR        RTCB                 rs12530-C
# 1134                             NaN        PIM3             rs117325373-G
# 1135                          PLXNB2      PLXNB2              rs79966207-C
# 1136                              NR      PLXNB2              rs79966207-?
# 1137                             NaN      PLXNB2              rs79966207-?
#
#      RISK ALLELE FREQUENCY P-VALUE  OR or BETA                95% CI (TEXT)  \
# 0                   0.2001   9E-12      0.0168  [0.012-0.022] unit increase
# 1                       NR   1E-34         NaN                          NaN
# 2                     0.04    2E-6         NaN                          NaN
# 3                     0.04    2E-6         NaN                          NaN
# 4                     0.04    2E-6         NaN                          NaN
# ...                    ...     ...         ...                          ...
# 1133      0.18432396929239    3E-6      0.1828    [0.11-0.26] unit increase
# 1134                    NR    2E-6      6.3469           [NR] unit decrease
# 1135                0.1776   5E-10      1.0630                           NR
# 1136                    NR    6E-9         NaN                          NaN
# 1137                    NR   3E-12         NaN                          NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 0                                       waist-hip ratio      GCST008996
# 1                                         FEV/FEC ratio      GCST007080
# 2            visceral:subcutaneous adipose tissue ratio      GCST001524
# 3                   visceral adipose tissue measurement      GCST001525
# 4                   visceral adipose tissue measurement      GCST001525
# ...                                                 ...             ...
# 1133                serum IgG glycosylation measurement      GCST001848
# 1134  schizophrenia, response to paliperidone, schiz...      GCST004040
# 1135                                         hair color      GCST006988
# 1136                                    body mass index      GCST009871
# 1137                            hair colour measurement      GCST007082
#
# [1138 rows x 15 columns]

# %% [markdown]
# ## Immune-related diseases associated with Neanderthal SNPs

# %% [markdown]
# ### Infections

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('influenza')]
# Out:
#             ID  Chromosome   Position          Source Chen  \
# 315  rs4261353           3  191695113  dannemann_only  Yes
#
#                            DISEASE/TRAIT REPORTED GENE(S)  \
# 315  Severe influenza A (H1N1) infection            FGF12
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 315  AC026320.2 - AC026320.1               rs4261353-?              0.001866
#
#     P-VALUE  OR or BETA  95% CI (TEXT)        MAPPED_TRAIT STUDY ACCESSION
# 315    1E-8       27.44  [4.948-152.1]  influenza A (H1N1)      GCST003123

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('wart')]
# Out:
#               ID  Chromosome  Position          Source Chen  DISEASE/TRAIT  \
# 960  rs150469170          14  77009234  dannemann_only  Yes  Plantar warts
#
#     REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 960               NR  AC008050.1             rs150469170-?
#
#     RISK ALLELE FREQUENCY P-VALUE  OR or BETA             95% CI (TEXT)  \
# 960                    NR    1E-6      0.3413  [0.2-0.48] unit increase
#
#                                     MAPPED_TRAIT STUDY ACCESSION
# 960  susceptibility to plantar warts measurement      GCST005005

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('HIV')]
# Out:
#              ID  Chromosome   Position          Source Chen  \
# 387  rs17291045           4  161506897            both  Yes
# 487  rs36111427           6  117753834  dannemann_only  Yes
# 636  rs72749479           9   83282271    simonti_only  Yes
# 637  rs72749483           9   83285174    simonti_only  Yes
# 688  rs17154929          10   44524675  dannemann_only  Yes
#
#                                          DISEASE/TRAIT REPORTED GENE(S)  \
# 387                                      HIV-1 control       intergenic
# 487  Time-dependent creatinine clearance change res...               NR
# 636  Time-dependent creatinine clearance change res...               NR
# 637  Time-dependent creatinine clearance change res...               NR
# 688                            HIV-associated dementia       intergenic
#
#                 MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 387               LINC02477              rs17291045-?                    NR
# 487              AL132671.2              rs36111427-?                   NaN
# 636       MTND2P9 - RPS19P6              rs72749479-?                   NaN
# 637       MTND2P9 - RPS19P6              rs72749483-?                   NaN
# 688  LINC00841 - AL137026.2              rs17154929-T                    NR
#
#     P-VALUE  OR or BETA 95% CI (TEXT)  \
# 387    5E-8         NaN           NaN
# 487    9E-6         NaN           NaN
# 636    7E-7         NaN           NaN
# 637    7E-7         NaN           NaN
# 688    1E-7         NaN           NaN
#
#                                           MAPPED_TRAIT STUDY ACCESSION
# 387                                    HIV-1 infection      GCST000549
# 487  response to tenofovir, HIV infection, creatini...      GCST006069
# 636  response to tenofovir, HIV infection, creatini...      GCST006069
# 637  response to tenofovir, HIV infection, creatini...      GCST006069
# 688                                      AIDS dementia      GCST001542

# %%
nean_catalog.loc[nean_catalog['DISEASE/TRAIT'].str.contains('Malaria')]
# Out:
#              ID  Chromosome  Position        Source Chen DISEASE/TRAIT  \
# 717  rs12788102          11   4790575  simonti_only  Yes       Malaria
#
#     REPORTED GENE(S)    MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 717              HBB  OR51F1, MMP26              rs12788102-A
#
#     RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT) MAPPED_TRAIT  \
# 717                    NR   2E-16        2.15   [1.79-2.59]      malaria
#
#     STUDY ACCESSION
# 717      GCST002033

# %% [markdown]
# ### Allergic diseases

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('allerg')]
# Out:
#               ID  Chromosome   Position          Source Chen  \
# 317  rs113048054           3  196343817  dannemann_only  Yes
# 322    rs4916533           3  196373582    simonti_only  Yes
# 323    rs4916533           3  196373582    simonti_only  Yes
# 334   rs11727978           4   38811051    simonti_only  Yes
# 335   rs66819621           4   38819403    simonti_only  Yes
# 371   rs45613035           4  123141070  dannemann_only  Yes
#
#                                       DISEASE/TRAIT REPORTED GENE(S)  \
# 317  Allergic disease (asthma, hay fever or eczema)               NR
# 322         Asthma or allergic disease (pleiotropy)            NRROS
# 323                         Hay fever and/or eczema               NR
# 334                                         Allergy       TLR1, TLR6
# 335                               Allergic rhinitis             TLR1
# 371                         Hay fever and/or eczema               NR
#
#                 MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 317  AC092933.2 - LINC01063             rs113048054-A               0.93413
# 322             NRROS, PIGX               rs4916533-?                    NR
# 323             NRROS, PIGX               rs4916533-C               0.91931
# 334                    TLR1              rs11727978-?                    NR
# 335                    TLR1              rs66819621-A                0.8428
# 371                KIAA1109              rs45613035-C               0.09838
#
#     P-VALUE  OR or BETA  95% CI (TEXT)                       MAPPED_TRAIT  \
# 317   4E-12    1.080497     [1.06-1.1]  Eczema, allergic rhinitis, asthma
# 322    2E-8    1.075269            NaN                    allergy, asthma
# 323   6E-10    1.070778    [1.05-1.09]          Eczema, allergic rhinitis
# 334   1E-15    1.083000  [1.062-1.104]                            allergy
# 335   2E-25    1.179941    [1.15-1.22]                  allergic rhinitis
# 371   6E-20    1.094000  [1.074-1.115]          Eczema, allergic rhinitis
#
#     STUDY ACCESSION
# 317      GCST009716
# 322      GCST007564
# 323      GCST009717
# 334      GCST003990
# 335      GCST009719
# 371      GCST009717

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('asthma')]
# Out:
#                ID  Chromosome   Position          Source Chen  \
# 317   rs113048054           3  196343817  dannemann_only  Yes
# 318   rs113048054           3  196343817  dannemann_only  Yes
# 319   rs112336433           3  196349004  dannemann_only  Yes
# 322     rs4916533           3  196373582    simonti_only  Yes
# 370    rs45613035           4  123141070  dannemann_only  Yes
# 372    rs45613035           4  123141070  dannemann_only  Yes
# 373    rs45613035           4  123141070  dannemann_only  Yes
# 374    rs45613035           4  123141070  dannemann_only  Yes
# 375    rs45613035           4  123141070  dannemann_only  Yes
# 378    rs62322662           4  123359569            both  Yes
# 379    rs62322662           4  123359569            both  Yes
# 592   rs117628011           8   76319166  dannemann_only  Yes
# 710    rs17642749          10  119647256    simonti_only  Yes
# 1085    rs4815617          20    3827309  dannemann_only  Yes
# 1115    rs2242900          21   36453837            both  Yes
#
#                                        DISEASE/TRAIT  \
# 317   Allergic disease (asthma, hay fever or eczema)
# 318                                           Asthma
# 319                                           Asthma
# 322          Asthma or allergic disease (pleiotropy)
# 370                         Asthma (childhood onset)
# 372                                           Asthma
# 373                                    Atopic asthma
# 374                                           Asthma
# 375                                           Asthma
# 378                                           Asthma
# 379                             Asthma (adult onset)
# 592                      Diisocyanate-induced asthma
# 710                         Asthma (sex interaction)
# 1085                                          Asthma
# 1115                                          Asthma
#
#                              REPORTED GENE(S)             MAPPED_GENE  \
# 317                                        NR  AC092933.2 - LINC01063
# 318                             NNROS, LRRC33  AC092933.2 - LINC01063
# 319                                     NRROS  AC092933.2 - LINC01063
# 322                                     NRROS             NRROS, PIGX
# 370                                        NR                KIAA1109
# 372      ADAD1, IL2, IL21, IL21-AS1, KIAA1109                KIAA1109
# 373                                        NR                KIAA1109
# 374                                  KIAA1109                KIAA1109
# 375   KIAA1109, ADAD1, IL2, TRPC3, BBS7, IL21                KIAA1109
# 378                                ADAD1, IL2             ADAD1 - IL2
# 379                                ADAD1, IL2             ADAD1 - IL2
# 592                                intergenic           PKMP4 - HNF4G
# 710                                 RAB11FIP2  AL513324.1 - RAB11FIP2
# 1085                                 KIAA1271            AP5S1 - MAVS
# 1115                                    RUNX1                   RUNX1
#
#      STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 317              rs113048054-A               0.93413   4E-12    1.080497
# 318              rs113048054-G               0.06587   3E-11         NaN
# 319              rs112336433-C               0.93272    3E-8    1.069407
# 322                rs4916533-?                    NR    2E-8    1.075269
# 370               rs45613035-?                    NR   9E-12         NaN
# 372               rs45613035-C              0.098644   1E-12    1.077323
# 373               rs45613035-?                    NR   5E-16         NaN
# 374               rs45613035-C                    NR   6E-19    1.107000
# 375               rs45613035-C               0.09872   5E-14    1.081750
# 378               rs62322662-G                    NR   2E-18    1.119000
# 379               rs62322662-?                    NR   8E-10    1.084000
# 592              rs117628011-A                 0.054    5E-6    3.060000
# 710               rs17642749-G                 0.086    4E-7    2.970000
# 1085               rs4815617-?                    NR    8E-6         NaN
# 1115               rs2242900-G                  0.14   2E-18         NaN
#
#      95% CI (TEXT)                         MAPPED_TRAIT STUDY ACCESSION
# 317     [1.06-1.1]    Eczema, allergic rhinitis, asthma      GCST009716
# 318            NaN                               asthma      GCST009720
# 319    [1.05-1.09]                               asthma      GCST008916
# 322            NaN                      allergy, asthma      GCST007564
# 370            NaN               childhood onset asthma      GCST009841
# 372     [1.06-1.1]                               asthma      GCST008916
# 373            NaN                        atopic asthma      GCST009850
# 374    [1.09-1.13]                               asthma      GCST007798
# 375    [1.06-1.10]                               asthma      GCST009798
# 378    [1.09-1.14]                               asthma      GCST007798
# 379    [1.06-1.11]                   adult onset asthma      GCST007799
# 592    [1.85-5.04]     response to diisocyanate, asthma      GCST002875
# 710    [1.90-4.63]  sex interaction measurement, asthma      GCST002445
# 1085           NaN                               asthma      GCST000576
# 1115           NaN                               asthma      GCST010043

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Eczema')]
# Out:
#                ID  Chromosome   Position          Source Chen  \
# 317   rs113048054           3  196343817  dannemann_only  Yes
# 321    rs12152276           3  196368501  dannemann_only  Yes
# 323     rs4916533           3  196373582    simonti_only  Yes
# 371    rs45613035           4  123141070  dannemann_only  Yes
# 376    rs45613035           4  123141070  dannemann_only  Yes
# 1116   rs73203093          21   36457506  dannemann_only  Yes
#
#                                        DISEASE/TRAIT REPORTED GENE(S)  \
# 317   Allergic disease (asthma, hay fever or eczema)               NR
# 321                                           Eczema              NaN
# 323                          Hay fever and/or eczema               NR
# 371                          Hay fever and/or eczema               NR
# 376                                           Eczema              NaN
# 1116                                          Eczema              NaN
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 317   AC092933.2 - LINC01063             rs113048054-A               0.93413
# 321              PIGX, NRROS              rs12152276-?                    NR
# 323              NRROS, PIGX               rs4916533-C               0.91931
# 371                 KIAA1109              rs45613035-C               0.09838
# 376                 KIAA1109              rs45613035-?                    NR
# 1116                   RUNX1              rs73203093-?                    NR
#
#      P-VALUE  OR or BETA  95% CI (TEXT)                       MAPPED_TRAIT  \
# 317    4E-12    1.080497     [1.06-1.1]  Eczema, allergic rhinitis, asthma
# 321    7E-10         NaN            NaN                             Eczema
# 323    6E-10    1.070778    [1.05-1.09]          Eczema, allergic rhinitis
# 371    6E-20    1.094000  [1.074-1.115]          Eczema, allergic rhinitis
# 376    2E-26         NaN            NaN                             Eczema
# 1116    7E-9         NaN            NaN                             Eczema
#
#      STUDY ACCESSION
# 317       GCST009716
# 321       GCST007075
# 323       GCST009717
# 371       GCST009717
# 376       GCST007075
# 1116      GCST007075

# %% [markdown]
# ### Autoimmune/autoinflammatory diseases

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('lupus')]
# Out:
#               ID  Chromosome   Position          Source Chen  \
# 96    rs34889541           1  198594769  dannemann_only  Yes
# 97    rs34889541           1  198594769  dannemann_only  Yes
# 536   rs35000415           7  128585616  dannemann_only  Yes
# 537   rs35000415           7  128585616  dannemann_only  Yes
# 538   rs35000415           7  128585616  dannemann_only  Yes
# 540   rs10488631           7  128594183  dannemann_only  Yes
# 541   rs10488631           7  128594183  dannemann_only  Yes
# 545   rs10488631           7  128594183  dannemann_only  Yes
# 552   rs10488631           7  128594183  dannemann_only  Yes
# 561   rs12706861           7  128616582  dannemann_only  Yes
# 567   rs13239597           7  128695983            both  Yes
# 912   rs11059927          12  129294333  dannemann_only  Yes
# 913    rs1385374          12  129300694  dannemann_only  Yes
# 914    rs1385374          12  129300694  dannemann_only  Yes
# 1016   rs4252665          17   37885383  dannemann_only  Yes
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 96                         Systemic lupus erythematosus      PTPRC, CD45
# 97                         Systemic lupus erythematosus      PTPRC, CD45
# 536                        Systemic lupus erythematosus             IRF5
# 537                        Systemic lupus erythematosus             IRF5
# 538                        Systemic lupus erythematosus      IRF5, TNPO3
# 540                        Systemic lupus erythematosus             IRF5
# 541                        Systemic lupus erythematosus      TNPO3, IRF5
# 545                        Systemic lupus erythematosus            TNPO3
# 552                        Systemic lupus erythematosus      IRF5, TNPO3
# 561                        Systemic lupus erythematosus      IRF5, TNPO3
# 567   Systemic lupus erythematosus and Systemic scle...      TNPO3, IRF5
# 912                        Systemic lupus erythematosus          SLC15A4
# 913                        Systemic lupus erythematosus          SLC15A4
# 914                        Systemic lupus erythematosus          SLC15A4
# 1016                       Systemic lupus erythematosus     ERBB2, MIEN1
#
#              MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 96    AL157402.1 - PTPRC              rs34889541-G                  0.86
# 97    AL157402.1 - PTPRC              rs34889541-G                  0.93
# 536                 IRF5              rs35000415-?                 0.108
# 537                 IRF5              rs35000415-T                   NaN
# 538                 IRF5              rs35000415-T                    NR
# 540   AC025594.2 - TNPO3              rs10488631-C                  0.11
# 541   AC025594.2 - TNPO3              rs10488631-C                  0.12
# 545   AC025594.2 - TNPO3              rs10488631-C                  0.11
# 552   AC025594.2 - TNPO3              rs10488631-C                   NaN
# 561                TNPO3              rs12706861-T                 0.118
# 567               TPI1P2              rs13239597-?                    NR
# 912              SLC15A4              rs11059927-C                 0.104
# 913              SLC15A4               rs1385374-A                  0.20
# 914              SLC15A4               rs1385374-A                  0.17
# 1016        ERBB2, MIEN1               rs4252665-A                    NR
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 96     3E-10    1.282051   [1.19-1.39]
# 97     2E-12    1.234568   [1.16-1.32]
# 536    2E-45    1.800000          [NR]
# 537    1E-60    1.830000          [NR]
# 538    1E-99    1.820000   [1.69-1.96]
# 540    7E-18    1.920000   [1.66-2.22]
# 541    2E-11         NaN           NaN
# 545    2E-13    1.829000  [1.684-1.99]
# 552   9E-110    1.920000   [1.81–2.03]
# 561    4E-71    1.760000   [1.65-1.87]
# 567    1E-29    1.664000          [NR]
# 912     2E-8    1.210000   [1.13-1.30]
# 913    2E-11    1.260000   [1.18-1.35]
# 914     8E-8    1.410000           NaN
# 1016   2E-12    1.460000   [1.26-1.70]
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 96                         systemic lupus erythematosus      GCST003622
# 97                         systemic lupus erythematosus      GCST003622
# 536                        systemic lupus erythematosus      GCST003622
# 537                        systemic lupus erythematosus      GCST003156
# 538                        systemic lupus erythematosus      GCST005752
# 540                        systemic lupus erythematosus      GCST000996
# 541                        systemic lupus erythematosus      GCST000144
# 545                        systemic lupus erythematosus      GCST002463
# 552                        systemic lupus erythematosus      GCST003155
# 561                        systemic lupus erythematosus      GCST007400
# 567   systemic scleroderma, systemic lupus erythemat...      GCST002069
# 912                        systemic lupus erythematosus      GCST007400
# 913                        systemic lupus erythematosus      GCST000507
# 914                        systemic lupus erythematosus      GCST001795
# 1016                       systemic lupus erythematosus      GCST005752

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('rheumatoid')]
# Out:
#              ID  Chromosome   Position          Source Chen  \
# 550  rs10488631           7  128594183  dannemann_only  Yes
# 574   rs2306848           7  129962414    simonti_only  Yes
# 950   rs3783782          14   61940675  dannemann_only  Yes
# 951   rs3783782          14   61940675  dannemann_only  Yes
# 952   rs3783782          14   61940675  dannemann_only  Yes
# 953   rs3783782          14   61940675  dannemann_only  Yes
#
#             DISEASE/TRAIT REPORTED GENE(S)         MAPPED_GENE  \
# 550  Rheumatoid arthritis             IRF5  AC025594.2 - TNPO3
# 574  Rheumatoid arthritis             CPA4                CPA4
# 950  Rheumatoid arthritis            PRKCH               PRKCH
# 951  Rheumatoid arthritis            PRKCH               PRKCH
# 952  Rheumatoid arthritis            PRKCH               PRKCH
# 953  Rheumatoid arthritis            PRKCH               PRKCH
#
#     STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 550              rs10488631-C                  0.11   4E-11    1.190000
# 574               rs2306848-G                 0.948   6E-12         NaN
# 950               rs3783782-A                  0.09    2E-9    1.140000
# 951               rs3783782-A                  0.22    4E-9    1.140000
# 952               rs3783782-A                    NR    1E-7    0.151127
# 953               rs3783782-A                  0.23    1E-7    0.160620
#
#                    95% CI (TEXT)          MAPPED_TRAIT STUDY ACCESSION
# 550                         [NR]  rheumatoid arthritis      GCST000679
# 574                          NaN  rheumatoid arthritis      GCST007843
# 950                  [1.09-1.18]  rheumatoid arthritis      GCST002318
# 951                  [1.09-1.19]  rheumatoid arthritis      GCST002318
# 952  [0.095-0.207] unit increase  rheumatoid arthritis      GCST006959
# 953     [0.1-0.22] unit increase  rheumatoid arthritis      GCST006959

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('scleroderma')]
# Out:
#              ID  Chromosome   Position          Source Chen  \
# 542  rs10488631           7  128594183  dannemann_only  Yes
# 544  rs10488631           7  128594183  dannemann_only  Yes
# 546  rs10488631           7  128594183  dannemann_only  Yes
# 547  rs10488631           7  128594183  dannemann_only  Yes
# 548  rs10488631           7  128594183  dannemann_only  Yes
# 549  rs10488631           7  128594183  dannemann_only  Yes
# 553  rs10488631           7  128594183  dannemann_only  Yes
# 554  rs10488631           7  128594183  dannemann_only  Yes
# 555  rs10488631           7  128594183  dannemann_only  Yes
# 556  rs10488631           7  128594183  dannemann_only  Yes
# 557  rs10488631           7  128594183  dannemann_only  Yes
# 558  rs10488631           7  128594183  dannemann_only  Yes
# 560  rs10488631           7  128594183  dannemann_only  Yes
# 562  rs12534421           7  128624073  dannemann_only  Yes
# 563  rs12534421           7  128624073  dannemann_only  Yes
# 564  rs36073657           7  128651522  dannemann_only  Yes
# 566  rs62478615           7  128684316    simonti_only  Yes
# 567  rs13239597           7  128695983            both  Yes
# 568  rs13239597           7  128695983            both  Yes
# 569  rs17340351           7  128708797    simonti_only  Yes
# 570  rs17340351           7  128708797    simonti_only  Yes
# 571  rs17340351           7  128708797    simonti_only  Yes
#
#                                          DISEASE/TRAIT REPORTED GENE(S)  \
# 542                                 Systemic sclerosis       TNPO, IRF5
# 544                                 Systemic sclerosis      TNPO3, IRF5
# 546                                 Systemic sclerosis             IRF5
# 547                                 Systemic sclerosis             IRF5
# 548                                 Systemic sclerosis             IRF5
# 549                                 Systemic sclerosis             IRF5
# 553               Diffuse cutaneous systemic sclerosis            TNPO3
# 554      Systemic sclerosis (anti-centromere-positive)      IRF5, TNPO3
# 555   Systemic sclerosis (anti-topoisomerase-positive)            TNPO3
# 556             Limited cutaneous systemic scleroderma      TNPO3, IRF5
# 557             Limited cutaneous systemic scleroderma             IRF5
# 558               Diffuse cutaneous systemic sclerosis             IRF5
# 560                                 Systemic sclerosis      IRF5, TNPO4
# 562               Diffuse cutaneous systemic sclerosis             IRF5
# 563                                 Systemic sclerosis             IRF5
# 564                                 Systemic sclerosis      IRF5, TNPO3
# 566                                 Systemic sclerosis             IRF5
# 567  Systemic lupus erythematosus and Systemic scle...      TNPO3, IRF5
# 568             Limited cutaneous systemic scleroderma            TNPO3
# 569                                 Systemic sclerosis            TNPO3
# 570               Diffuse cutaneous systemic sclerosis            TNPO3
# 571   Systemic sclerosis (anti-topoisomerase-positive)            TNPO3
#
#                  MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 542       AC025594.2 - TNPO3              rs10488631-C                    NR
# 544       AC025594.2 - TNPO3              rs10488631-C                  0.09
# 546       AC025594.2 - TNPO3              rs10488631-?                    NR
# 547       AC025594.2 - TNPO3              rs10488631-?                    NR
# 548       AC025594.2 - TNPO3              rs10488631-?                    NR
# 549       AC025594.2 - TNPO3              rs10488631-?                    NR
# 553       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 554       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 555       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 556       AC025594.2 - TNPO3              rs10488631-?                    NR
# 557       AC025594.2 - TNPO3              rs10488631-?                    NR
# 558       AC025594.2 - TNPO3              rs10488631-?                   NaN
# 560       AC025594.2 - TNPO3              rs10488631-C                    NR
# 562                    TNPO3              rs12534421-?                    NR
# 563                    TNPO3              rs12534421-?                    NR
# 564                    TNPO3              rs36073657-T                   0.1
# 566                    TNPO3              rs62478615-?                   NaN
# 567                   TPI1P2              rs13239597-?                    NR
# 568                   TPI1P2              rs13239597-?                    NR
# 569  AC018639.1 - AC011005.2              rs17340351-?                    NR
# 570  AC018639.1 - AC011005.2              rs17340351-?                    NR
# 571  AC018639.1 - AC011005.2              rs17340351-?                    NR
#
#     P-VALUE  OR or BETA 95% CI (TEXT)  \
# 542   2E-13       1.500   [1.35-1.67]
# 544    4E-7       1.350   [1.20-1.51]
# 546   2E-10       1.500   [1.32-1.69]
# 547    8E-7       1.630   [1.34-1.98]
# 548    1E-9       1.610   [1.38-1.88]
# 549    2E-7       1.520   [1.30-1.79]
# 553    1E-9         NaN           NaN
# 554    9E-7         NaN           NaN
# 555    4E-7         NaN           NaN
# 556   3E-10         NaN           NaN
# 557    9E-7         NaN           NaN
# 558    1E-9         NaN           NaN
# 560    6E-7       1.630   [1.34-1.97]
# 562    4E-6         NaN           NaN
# 563   7E-10         NaN           NaN
# 564   3E-21       1.400           NaN
# 566   1E-10       1.530           NaN
# 567   1E-29       1.664          [NR]
# 568    9E-7         NaN           NaN
# 569   2E-10         NaN           NaN
# 570    7E-7         NaN           NaN
# 571    1E-8         NaN           NaN
#
#                                           MAPPED_TRAIT STUDY ACCESSION
# 542                               systemic scleroderma      GCST000650
# 544                               systemic scleroderma      GCST001146
# 546                               systemic scleroderma      GCST001160
# 547                               systemic scleroderma      GCST001156
# 548                               systemic scleroderma      GCST001156
# 549                               systemic scleroderma      GCST001156
# 553                                diffuse scleroderma      GCST005335
# 554  anti-centromere-antibody-positive systemic scl...      GCST005333
# 555  anti-topoisomerase-I-antibody-positive systemi...      GCST005332
# 556                                limited scleroderma      GCST005334
# 557                                limited scleroderma      GCST005555
# 558                                diffuse scleroderma      GCST005335
# 560                               systemic scleroderma      GCST006493
# 562                                diffuse scleroderma      GCST005553
# 563                               systemic scleroderma      GCST005554
# 564                               systemic scleroderma      GCST009131
# 566                               systemic scleroderma      GCST005534
# 567  systemic scleroderma, systemic lupus erythemat...      GCST002069
# 568                                limited scleroderma      GCST005555
# 569                               systemic scleroderma      GCST005554
# 570                                diffuse scleroderma      GCST005553
# 571  anti-topoisomerase-I-antibody-positive systemi...      GCST005551

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Sjogren')]
# Out:
#              ID  Chromosome   Position Source Chen       DISEASE/TRAIT  \
# 565  rs17339836           7  128681062   both  Yes  Sjögren's syndrome
#
#     REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 565      IRF5, TNPO3       TNPO3              rs17339836-T
#
#     RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)      MAPPED_TRAIT  \
# 565                  0.12   2E-16        1.58   [1.36–1.84]  Sjogren syndrome
#
#     STUDY ACCESSION
# 565      GCST004878

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Grave')]
# Out:
#            ID  Chromosome   Position          Source Chen    DISEASE/TRAIT  \
# 65  rs1265883           1  160464911  dannemann_only  Yes  Graves' disease
#
#    REPORTED GENE(S) MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 65           SLAMF6      SLAMF6               rs1265883-C
#
#    RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)    MAPPED_TRAIT  \
# 65                   0.1   2E-18        1.34   [1.25-1.43]  Graves disease
#
#    STUDY ACCESSION
# 65      GCST001984

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('glomerulonephritis')]
# Out:
#              ID  Chromosome   Position        Source Chen  \
# 196  rs17830558           2  160878364  simonti_only  Yes
# 199  rs17831251           2  160914156  simonti_only  Yes
# 200  rs17831251           2  160914156  simonti_only  Yes
# 201  rs17831251           2  160914156  simonti_only  Yes
# 202   rs4664308           2  160917497  simonti_only  Yes
#
#                          DISEASE/TRAIT            REPORTED GENE(S)  \
# 196             Membranous nephropathy                      PLA2R1
# 199             Membranous nephropathy                      PLA2R1
# 200             Membranous nephropathy                      PLA2R1
# 201             Membranous nephropathy                      PLA2R1
# 202  Idiopathic membranous nephropathy  LY75, ITGB6, PLA2R1, RBMS1
#
#     MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  \
# 196      PLA2R1              rs17830558-T                  0.52   4E-10
# 199      PLA2R1              rs17831251-C                    NR  5E-103
# 200      PLA2R1              rs17831251-C                  0.61   5E-48
# 201      PLA2R1              rs17831251-C                   0.7   4E-61
# 202      PLA2R1               rs4664308-A                  0.43   9E-29
#
#      OR or BETA 95% CI (TEXT)                   MAPPED_TRAIT STUDY ACCESSION
# 196        1.87   [1.54–2.28]  membranous glomerulonephritis      GCST003402
# 199        2.25   [2.09-2.42]  membranous glomerulonephritis      GCST010004
# 200        1.98   [1.81-2.17]  membranous glomerulonephritis      GCST010005
# 201        2.81   [2.48-3.17]  membranous glomerulonephritis      GCST010006
# 202        2.28   [1.96-2.64]  membranous glomerulonephritis      GCST000984

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('colitis')]
# Out:
#               ID  Chromosome  Position          Source Chen  \
# 874   rs12422544          12  40528432            both  Yes
# 1046   rs7236492          18  77220616  dannemann_only  Yes
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 874                                  Ulcerative colitis               NR
# 1046  Chronic inflammatory diseases (ankylosing spon...           NFATC1
#
#               MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 874   SLC2A13 - LINC02555              rs12422544-G               0.01915
# 1046   AC018445.5, NFATC1               rs7236492-?                    NR
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 874     3E-6    1.215345    [1.13-1.3]
# 1046    1E-7         NaN           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 874                                  ulcerative colitis      GCST003045
# 1046  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('Crohn')]
# Out:
#               ID  Chromosome  Position          Source Chen  \
# 692    rs7076156          10  64415184  dannemann_only  Yes
# 875   rs12422544          12  40528432            both  Yes
# 876   rs11175593          12  40601940  dannemann_only  Yes
# 923   rs17061048          13  40833012  dannemann_only  Yes
# 1044   rs7236492          18  77220616  dannemann_only  Yes
# 1046   rs7236492          18  77220616  dannemann_only  Yes
#
#                                           DISEASE/TRAIT   REPORTED GENE(S)  \
# 692                                     Crohn's disease  ADO, ZNF365, ERG2
# 875                                     Crohn's disease                 NR
# 876                                     Crohn's disease       MUC19, LRRK2
# 923                                     Crohn's disease                 NR
# 1044                                    Crohn's disease        NFATC1, TST
# 1046  Chronic inflammatory diseases (ankylosing spon...             NFATC1
#
#                      MAPPED_GENE STRONGEST SNP-RISK ALLELE  \
# 692       AC067752.1, AC024598.1               rs7076156-G
# 875          SLC2A13 - LINC02555              rs12422544-G
# 876   LRRK2-DT, LRRK2, LINC02471              rs11175593-T
# 923                    LINC00598              rs17061048-A
# 1044          AC018445.5, NFATC1               rs7236492-G
# 1046          AC018445.5, NFATC1               rs7236492-?
#
#      RISK ALLELE FREQUENCY P-VALUE  OR or BETA 95% CI (TEXT)  \
# 692                  0.751    7E-9    1.190000   [1.10-1.30]
# 875                0.01915   4E-25    1.455191   [1.38-1.53]
# 876                   0.02   3E-10    1.540000          [NR]
# 923                   0.95    1E-7    1.161814   [1.11-1.22]
# 1044                  0.85    9E-9    1.104796   [1.07-1.14]
# 1046                    NR    1E-7         NaN           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 692                                     Crohn's disease      GCST001438
# 875                                     Crohn's disease      GCST003044
# 876                                     Crohn's disease      GCST000207
# 923                                     Crohn's disease      GCST003044
# 1044                                    Crohn's disease      GCST003044
# 1046  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('bowel')]
# Out:
#               ID  Chromosome  Position          Source Chen  \
# 924   rs17061048          13  40833012  dannemann_only  Yes
# 1045   rs7236492          18  77220616  dannemann_only  Yes
#
#                    DISEASE/TRAIT REPORTED GENE(S)         MAPPED_GENE  \
# 924   Inflammatory bowel disease               NR           LINC00598
# 1045  Inflammatory bowel disease      NFATC1, TST  AC018445.5, NFATC1
#
#      STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 924               rs17061048-A                  0.95    5E-9    1.145133
# 1045               rs7236492-G                  0.85    1E-8    1.083568
#
#      95% CI (TEXT)                MAPPED_TRAIT STUDY ACCESSION
# 924            NaN  inflammatory bowel disease      GCST003043
# 1045           NaN  inflammatory bowel disease      GCST003043

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('psoriasis')]
# Out:
#               ID  Chromosome   Position          Source Chen  \
# 414   rs12188351           5  168386089            both  Yes
# 693    rs7922314          10   64538279  dannemann_only  Yes
# 886    rs2066807          12   56740682  dannemann_only  Yes
# 887    rs2066807          12   56740682  dannemann_only  Yes
# 1046   rs7236492          18   77220616  dannemann_only  Yes
#
#                                           DISEASE/TRAIT REPORTED GENE(S)  \
# 414                           Inflammatory skin disease            SLIT3
# 693                                 Cutaneous psoriasis              ADO
# 886                                           Psoriasis     IL23A, STAT2
# 887                                           Psoriasis     IL23A, STAT2
# 1046  Chronic inflammatory diseases (ankylosing spon...           NFATC1
#
#              MAPPED_GENE STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY  \
# 414                SLIT3              rs12188351-?                    NR
# 693           AC067751.1               rs7922314-C                0.9206
# 886                STAT2               rs2066807-G              0.932351
# 887                STAT2               rs2066807-G              0.932351
# 1046  AC018445.5, NFATC1               rs7236492-?                    NR
#
#      P-VALUE  OR or BETA 95% CI (TEXT)  \
# 414     1E-8         NaN           NaN
# 693     2E-6        1.33            NR
# 886    1E-10        1.55   [1.35-1.77]
# 887    5E-12        1.40   [1.27-1.54]
# 1046    1E-7         NaN           NaN
#
#                                            MAPPED_TRAIT STUDY ACCESSION
# 414                                           psoriasis      GCST002740
# 693          cutaneous psoriasis measurement, psoriasis      GCST003269
# 886                                           psoriasis      GCST002874
# 887                                           psoriasis      GCST002874
# 1046  ankylosing spondylitis, psoriasis, ulcerative ...      GCST005537

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('celiac')]
# Out:
#              ID  Chromosome   Position          Source Chen   DISEASE/TRAIT  \
# 272  rs13098911           3   46235201            both  Yes  Celiac disease
# 377  rs62321692           4  123261530  dannemann_only  Yes  Celiac disease
#
#                         REPORTED GENE(S) MAPPED_GENE  \
# 272  CCRL2, CCR5, CCR9, CCR1, CCR2, CCR3        CCR3
# 377                             KIAA1109    KIAA1109
#
#     STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 272              rs13098911-A                  0.10   3E-17      1.3000
# 377              rs62321692-?                    NR    1E-8      0.1924
#
#      95% CI (TEXT)    MAPPED_TRAIT STUDY ACCESSION
# 272    [1.23-1.39]  celiac disease      GCST000612
# 377  unit decrease  celiac disease      GCST008489

# %%
nean_catalog.loc[nean_catalog['MAPPED_TRAIT'].str.contains('multiple sclerosis')]
# Out:
#              ID  Chromosome   Position          Source Chen  \
# 492  rs17780048           6  138179146  dannemann_only  Yes
#
#           DISEASE/TRAIT REPORTED GENE(S) MAPPED_GENE  \
# 492  Multiple sclerosis     LOC100130476     WAKMAR2
#
#     STRONGEST SNP-RISK ALLELE RISK ALLELE FREQUENCY P-VALUE  OR or BETA  \
# 492              rs17780048-C                    NR   5E-12      1.1008
#
#     95% CI (TEXT)        MAPPED_TRAIT STUDY ACCESSION
# 492            NR  multiple sclerosis      GCST009597

# %% [markdown]
# ## Do immune disease-associated Neanderthal SNPs show eQTL?

# %%
# Load eQTL data
fairfax_ori = pd.read_csv("../fairfax/tab2_a_cis_eSNPs.txt", sep="\t", usecols=["SNP", "Gene", "Min.dataset", "LPS2.FDR", "LPS24.FDR", "IFN.FDR", "Naive.FDR"])

fairfax_re = pd.read_csv('overlap_filtered_fairfax.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
fairfax_re.sort_values('pvalue', inplace=True)
fairfax_re.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

nedelec_re = pd.read_csv('overlap_filtered_nedelec.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
nedelec_re.sort_values('pvalue', inplace=True)
nedelec_re.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

quach = pd.read_csv('overlap_filtered_quach.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
quach.sort_values('pvalue', inplace=True)
quach.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

alasoo = pd.read_csv('overlap_filtered_alasoo.csv', usecols=['rsid', 'pvalue', 'gene_id', 'Condition', 'beta'])
alasoo.sort_values('pvalue', inplace=True)
alasoo.drop_duplicates(subset=['rsid', 'gene_id', 'Condition'], keep='first', inplace=True)

# %%
# Selected Neanderthal SNPs with immune disease associations
gwas = open('overlapped_SNPs.txt', 'r').read().splitlines()
gwas
# Out:
# ['rs4261353',
#  'rs150469170',
#  'rs2660',
#  'rs2384071',
#  'rs2384072',
#  'rs11466617',
#  'rs11466640',
#  'rs4274855',
#  'rs11725309',
#  'rs11722813',
#  'rs5743557',
#  'rs5743562',
#  'rs5743563',
#  'rs5743565',
#  'rs5743592',
#  'rs5743571',
#  'rs17582893',
#  'rs17582921',
#  'rs12788102',
#  'rs17291045',
#  'rs4916533',
#  'rs113048054',
#  'rs66819621',
#  'rs11727978',
#  'rs45613035',
#  'rs12152276',
#  'rs73203093',
#  'rs13239597',
#  'rs35000415',
#  'rs10488631',
#  'rs12706861',
#  'rs11059927',
#  'rs1385374',
#  'rs4252665',
#  'rs34889541',
#  'rs3783782',
#  'rs2306848',
#  'rs62478615',
#  'rs13239597',
#  'rs36073657',
#  'rs12534421',
#  'rs17340351',
#  'rs17339836',
#  'rs1265883',
#  'rs17830558',
#  'rs17831251',
#  'rs4664308',
#  'rs17061048',
#  'rs7236492',
#  'rs7076156',
#  'rs12422544',
#  'rs11175593',
#  'rs2066807',
#  'rs12188351',
#  'rs13098911',
#  'rs62321692',
#  'rs17780048']

# %%
# Overlap with original Fairfax eQTLs
ls = set(list(fairfax_ori.SNP)).intersection(gwas)
fairfax_ori.loc[fairfax_ori.SNP.isin(ls)]
# Out:
#               SNP    Gene  LPS2.FDR  LPS24.FDR       IFN.FDR  Naive.FDR  \
# 3532   rs11725309    TLR1  0.000099   0.210042  4.680000e-08        NaN
# 5823    rs7236492  NFATC1  0.254156   0.000012  2.129760e-04   0.002774
# 6359    rs2066807   CNPY2  0.074123   0.000780  6.555550e-04   0.034881
# 9990    rs7236492  NFATC1       NaN   0.000460  2.801852e-02   0.164114
# 12213   rs7236492  NFATC1       NaN   0.032637  1.839184e-01   0.022086
# 12676   rs2066807   TMEM4  0.295496   0.000184  2.863624e-01   0.046866
# 16655  rs11725309    TLR6       NaN   0.000439           NaN   0.234215
#
#       Min.dataset
# 3532          IFN
# 5823        LPS24
# 6359          IFN
# 9990        LPS24
# 12213       Naive
# 12676       LPS24
# 16655       LPS24

# %%
# Overlap with recomputed Fairfax eQTLs
ls = set(list(fairfax_re.rsid)).intersection(gwas)
fairfax_re.loc[fairfax_re.rsid.isin(ls)]
# Out:
#              rsid         pvalue          gene_id      beta Condition
# 30222      rs2660  1.977790e-137  ENSG00000089127  1.179160     Naive
# 7083       rs2660  7.975460e-130  ENSG00000089127  1.502870       IFN
# 7496    rs2384072  2.502920e-111  ENSG00000089127  1.431310       IFN
# 7489    rs2384071  2.567830e-111  ENSG00000089127  1.431740       IFN
# 30454   rs2384071  4.288830e-110  ENSG00000089127  1.103850     Naive
# ...           ...            ...              ...       ...       ...
# 11693  rs17582893   5.169010e-10  ENSG00000174125  0.217032      LPS2
# 17042  rs11466640   8.309440e-10  ENSG00000174125  0.205908     LPS24
# 18659   rs4274855   1.668790e-09  ENSG00000174125  0.200024     LPS24
# 32063   rs7236492   1.804790e-09  ENSG00000131196  0.105722     Naive
# 29867   rs2066807   1.983580e-09  ENSG00000170581 -0.186349     Naive
#
# [72 rows x 5 columns]

# %%
# Overlap with recomputed Nedelec eQTLs
ls = set(list(nedelec_re.rsid)).intersection(gwas)
nedelec_re.loc[nedelec_re.rsid.isin(ls)]
# Out:
#            rsid        pvalue          gene_id      beta   Condition
# 1674  rs2384071  1.765550e-13  ENSG00000111331  0.162116  Salmonella
# 1675  rs2384072  1.767620e-13  ENSG00000111331  0.162108  Salmonella
# 1616     rs2660  1.077880e-11  ENSG00000111331  0.157389  Salmonella

# %%
# Overlap with recomputed Quach eQTLs
ls = set(list(quach.rsid)).intersection(gwas)
quach.loc[quach.rsid.isin(ls)]
# Out:
#             rsid        pvalue          gene_id      beta Condition
# 916       rs2660  3.884100e-15  ENSG00000111331  0.197481       IAV
# 975    rs2384072  6.712570e-15  ENSG00000111331  0.194627       IAV
# 974    rs2384071  6.717330e-15  ENSG00000111331  0.194641       IAV
# 1017  rs11059927  4.876310e-12  ENSG00000139370 -0.264890       IAV
# 1024   rs1385374  4.880100e-12  ENSG00000139370 -0.264857       IAV
# 7240   rs2384071  4.871050e-10  ENSG00000111331  0.175183      R848
# 7241   rs2384072  4.875020e-10  ENSG00000111331  0.175165      R848
# 7182      rs2660  1.279440e-09  ENSG00000111331  0.172391      R848
# 8158  rs13098911  2.205190e-08  ENSG00000283646  0.684537     Naive

# %%
# Overlap with recomputed Alasoo eQTLs
ls = set(list(alasoo.rsid)).intersection(gwas)
alasoo.loc[alasoo.rsid.isin(ls)]
# Out:
#             rsid        pvalue          gene_id      beta        Condition
# 1124  rs13098911  5.543130e-11  ENSG00000223552 -0.816275             IFNg
# 2543  rs66819621  5.602500e-09  ENSG00000174125 -0.463299       Salmonella
# 636       rs2660  7.556660e-09  ENSG00000089127 -0.128276  IFNg+Salmonella
# 694    rs2384071  3.364780e-08  ENSG00000089127 -0.121321  IFNg+Salmonella
# 695    rs2384072  3.371730e-08  ENSG00000089127 -0.121283  IFNg+Salmonella
