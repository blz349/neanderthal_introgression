# %% [markdown]
# # Plot gene networks for overlapping recomputed Quach eQTLs
#
# This code plots the network of genes associated with recomputed Quach eQTLs for which the same variant has been identified as Neanderthal-introgressed by Dannemann *et al.* and/or Simonti *et al.* Monocytes in the Quach dataset were divided into 5 treatment groups: Influenza A virus (IAV), LPS, Pam3CSK4, R848 and Naive.
#
# Neanderthal SNPs from:
# 1. Dannemann M, Prufer K & Kelso J. Functional implications of Neandertal introgression in modern humans. *Genome Biol* 2017 **18**:61.
# 2. Simonti CN *et al.* The phenotypic legacy of admixture between modern humans and Neandertals. *Science* 2016 **351**:737-41.
#
# Recomputed Quach *et al.* (2016) eQTLs from:
# * [EMBL-EBI eQTL Catalogue](https://www.ebi.ac.uk/eqtl/Data_access/)
#
# ---

# %% [markdown]
# First, the list of genes and associated p-values for each condition was obtained from: `/well/jknight/shiyao/data/quach/genes_*.txt`. This was inputted into the XGR R package  to obtain subnet edge information, using the following code.
#
# ```r
# # Gene enrichment/network analysis
# library(XGR)
# library(RCircos)
# RData.location <- "http://galahad.well.ox.ac.uk/bigdata_dev/"
#
# # Get subnet
# dd <- read.csv('genes_*.txt', sep = '\t',               # where * refers to IAV/LPS/Pam3CSK4/R848/naive
#                header = FALSE, check.names = TRUE)
# design <- structure(dd$V2, names = as.character(dd$V1))
# subnet <- xSubneterGenes(design, network="STRING_high",
#                          STRING.only=NA, seed.genes=T)  # seed.genes=F to include non-input genes
#
# ## Visualise subnet
# # Colored according to input significance
# xVisNet(g=subnet, pattern=-log10(as.numeric(V(subnet)$significance)), vertex.shape="sphere", colormap="wyr")
# # Colored according to transformed scores
# xVisNet(g=subnet, pattern=as.numeric(V(subnet)$score), vertex.shape="sphere")
#
# ## Save subnet results to the files called 'subnet_edges.txt' and 'subnet_nodes.txt'
# edges <- igraph::get.data.frame(subnet, what="edges")
# utils::write.table(edges, file="subnet_edges.txt", sep="\t", row.names=FALSE)
# output <- igraph::get.data.frame(subnet, what="vertices")
# utils::write.table(output, file="subnet_nodes.txt", sep="\t", row.names=FALSE)
# ```
#
# ---

# %% [markdown]
# Next, gene networks were plotted in Python using the subnet_edges.txt files.

# %%
# Import modules
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline

# %% [markdown]
# ### IAV (input genes only)

# %%
lines = open('subnet_edges_IAV.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), with_labels=True, node_color='lightblue', edge_color='turquoise', node_size=2000, font_size=23)
plt.show()

# %% [markdown]
# ### IAV (including non-input genes)

# %%
lines = open('subnet_edges_IAV_expand.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

# What are the central nodes:
central_nodes = nx.betweenness_centrality(G)
maxi = ''
maxo = 0
for item in central_nodes:
    if central_nodes[item] > 0.3:
        print(item, central_nodes[item] * 100)
    if central_nodes[item] > maxo:
        maxo = central_nodes[item]
        maxi = item

for node in G:
    if G.degree(node) > 3:
        print(node, G.degree(node))
# Out:
# UBA52 84.55882352941177
# CBL 32.35294117647059
# UBA52 15
# MAPK14 4
# CBL 4

# %%
# Highlight central nodes
key_nodes = ['UBA52', 'CBL']
genes = open('genes_IAV.txt', 'r').read().splitlines()
lines = open('subnet_edges_IAV_expand.txt', 'r').read().splitlines()
for line in lines[1:]:
    temp = line.split('\t')
    
    # Differentiate input and non-input genes
    if temp[0].strip('"') in genes or temp[1].strip('"') in genes:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='green')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='blue')
    else:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='seagreen')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='gray')
            
edges = G.edges()
colors = [G[u][v]['color'] for u, v in edges]

node_map = []
color_map = []
legend_to_do = []
for node in G:
    if node.rstrip('"').lstrip('"') in genes:
        if node in key_nodes:
            color_map.append('lightgreen')
        else:
            color_map.append('lightblue')
    else:
        if node.rstrip('"').lstrip('"') in key_nodes:
            color_map.append('darkseagreen')
        else:
            color_map.append('lightgray')
legend_to_do.append(('Central nodes (input)', 'lightgreen'))
legend_to_do.append(('Central nodes (non-input)', 'darkseagreen'))
legend_to_do.append(('Input genes', 'lightblue'))
legend_to_do.append(('Non-input genes', 'lightgray'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), edges=edges, edge_color=colors, with_labels=True,
        node_color=color_map, font_size=25, node_size=2000)  

custom_lines = []
labels = []
for item in legend_to_do:
    custom_lines.append(Line2D([0], [0], color=item[1], lw=10))
    labels.append(item[0])

plt.legend(custom_lines, labels, loc=0, fontsize='xx-large')
plt.show()

# %% [markdown]
# ---
#
# ### LPS (input genes only)

# %%
lines = open('subnet_edges_LPS.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), with_labels=True, node_color='lightblue', edge_color='turquoise', node_size=2000, font_size=23)
plt.show()

# %% [markdown]
# ### LPS (including non-input genes)

# %%
lines = open('subnet_edges_LPS_expand.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

# What are the central nodes:
central_nodes = nx.betweenness_centrality(G)
maxi = ''
maxo = 0
for item in central_nodes:
    if central_nodes[item] > 0.4:
        print(item, central_nodes[item] * 100)
    if central_nodes[item] > maxo:
        maxo = central_nodes[item]
        maxi = item

for node in G:
    if G.degree(node) > 6:
        print(node, G.degree(node))
# Out:
# UBA52 96.1038961038961
# UBA52 19

# %%
# Highlight central nodes
key_nodes = ['UBA52']
genes = open('genes_LPS.txt', 'r').read().splitlines()
lines = open('subnet_edges_LPS_expand.txt', 'r').read().splitlines()
for line in lines[1:]:
    temp = line.split('\t')
    
    # Differentiate input and non-input genes
    if temp[0].strip('"') in genes or temp[1].strip('"') in genes:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='green')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='blue')
    else:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='seagreen')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='gray')
            
edges = G.edges()
colors = [G[u][v]['color'] for u, v in edges]

node_map = []
color_map = []
legend_to_do = []
for node in G:
    if node.rstrip('"').lstrip('"') in genes:
        if node in key_nodes:
            color_map.append('lightgreen')
        else:
            color_map.append('lightblue')
    else:
        if node.rstrip('"').lstrip('"') in key_nodes:
            color_map.append('darkseagreen')
        else:
            color_map.append('lightgray')
legend_to_do.append(('Central nodes (input)', 'lightgreen'))
legend_to_do.append(('Central nodes (non-input)', 'darkseagreen'))
legend_to_do.append(('Input genes', 'lightblue'))
legend_to_do.append(('Non-input genes', 'lightgray'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), edges=edges, edge_color=colors, with_labels=True,
        node_color=color_map, font_size=25, node_size=2000)  

custom_lines = []
labels = []
for item in legend_to_do:
    custom_lines.append(Line2D([0], [0], color=item[1], lw=10))
    labels.append(item[0])

plt.legend(custom_lines, labels, loc=0, fontsize='xx-large')
plt.show()

# %% [markdown]
# ---
#
# ### Pam3CSK4 (input genes only)

# %%
lines = open('subnet_edges_Pam.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), with_labels=True, node_color='lightblue', edge_color='turquoise', node_size=2000, font_size=23)
plt.show()

# %% [markdown]
# ### Pam3CSK4 (including non-input genes)

# %%
lines = open('subnet_edges_Pam_expand.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

# What are the central nodes:
central_nodes = nx.betweenness_centrality(G)
maxi = ''
maxo = 0
for item in central_nodes:
    if central_nodes[item] > 0.4:
        print(item, central_nodes[item] * 100)
    if central_nodes[item] > maxo:
        maxo = central_nodes[item]
        maxi = item

for node in G:
    if G.degree(node) > 5:
        print(node, G.degree(node))
# Out:
# UBA52 94.15204678362572
# UBA52 15

# %%
# Highlight central nodes
key_nodes = ['UBA52']
genes = open('genes_Pam3CSK4.txt', 'r').read().splitlines()
lines = open('subnet_edges_Pam_expand.txt', 'r').read().splitlines()
for line in lines[1:]:
    temp = line.split('\t')
    
    # Differentiate input and non-input genes
    if temp[0].strip('"') in genes or temp[1].strip('"') in genes:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='green')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='blue')
    else:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='seagreen')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='gray')
            
edges = G.edges()
colors = [G[u][v]['color'] for u, v in edges]

node_map = []
color_map = []
legend_to_do = []
for node in G:
    if node.rstrip('"').lstrip('"') in genes:
        if node in key_nodes:
            color_map.append('lightgreen')
        else:
            color_map.append('lightblue')
    else:
        if node.rstrip('"').lstrip('"') in key_nodes:
            color_map.append('darkseagreen')
        else:
            color_map.append('lightgray')
legend_to_do.append(('Central nodes (input)', 'lightgreen'))
legend_to_do.append(('Central nodes (non-input)', 'darkseagreen'))
legend_to_do.append(('Input genes', 'lightblue'))
legend_to_do.append(('Non-input genes', 'lightgray'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), edges=edges, edge_color=colors, with_labels=True,
        node_color=color_map, font_size=25, node_size=2000)  

custom_lines = []
labels = []
for item in legend_to_do:
    custom_lines.append(Line2D([0], [0], color=item[1], lw=10))
    labels.append(item[0])

plt.legend(custom_lines, labels, loc=0, fontsize='xx-large')
plt.show()

# %% [markdown]
# ---
#
# ### R848 (input genes only)

# %%
lines = open('subnet_edges_R848.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), with_labels=True, node_color='lightblue', edge_color='turquoise', node_size=2000, font_size=23)
plt.show()

# %% [markdown]
# ### R848 (including non-input genes)

# %%
lines = open('subnet_edges_R848_expand.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

# What are the central nodes:
central_nodes = nx.betweenness_centrality(G)
maxi = ''
maxo = 0
for item in central_nodes:
    if central_nodes[item] > 0.4:
        print(item, central_nodes[item] * 100)
    if central_nodes[item] > maxo:
        maxo = central_nodes[item]
        maxi = item

for node in G:
    if G.degree(node) > 5:
        print(node, G.degree(node))
# Out:
# UBA52 96.44268774703558
# UBA52 19

# %%
# Highlight central nodes
key_nodes = ['UBA52']
genes = open('genes_R848.txt', 'r').read().splitlines()
lines = open('subnet_edges_R848_expand.txt', 'r').read().splitlines()
for line in lines[1:]:
    temp = line.split('\t')
    
    # Differentiate input and non-input genes
    if temp[0].strip('"') in genes or temp[1].strip('"') in genes:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='green')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='blue')
    else:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='seagreen')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='gray')
            
edges = G.edges()
colors = [G[u][v]['color'] for u, v in edges]

node_map = []
color_map = []
legend_to_do = []
for node in G:
    if node.rstrip('"').lstrip('"') in genes:
        if node in key_nodes:
            color_map.append('lightgreen')
        else:
            color_map.append('lightblue')
    else:
        if node.rstrip('"').lstrip('"') in key_nodes:
            color_map.append('darkseagreen')
        else:
            color_map.append('lightgray')
legend_to_do.append(('Central nodes (input)', 'lightgreen'))
legend_to_do.append(('Central nodes (non-input)', 'darkseagreen'))
legend_to_do.append(('Input genes', 'lightblue'))
legend_to_do.append(('Non-input genes', 'lightgray'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), edges=edges, edge_color=colors, with_labels=True,
        node_color=color_map, font_size=25, node_size=2000)  

custom_lines = []
labels = []
for item in legend_to_do:
    custom_lines.append(Line2D([0], [0], color=item[1], lw=10))
    labels.append(item[0])

plt.legend(custom_lines, labels, loc=0, fontsize='xx-large')
plt.show()

# %% [markdown]
# ---
#
# ### Naive (input genes only)

# %%
lines = open('subnet_edges_naive.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), with_labels=True, node_color='lightblue', edge_color='turquoise', node_size=2000, font_size=23)
plt.show()

# %% [markdown]
# ---
#
# ### Naive (including non-input genes)

# %%
lines = open('subnet_edges_naive_expand.txt', 'r').read().splitlines()
G = nx.Graph()
for line in lines[1:]:
    temp = line.split('\t')
    G.add_edge(temp[0].strip('"'), temp[1].strip('"'))

# What are the central nodes:
central_nodes = nx.betweenness_centrality(G)
maxi = ''
maxo = 0
for item in central_nodes:
    if central_nodes[item] > 0.3:
        print(item, central_nodes[item] * 100)
    if central_nodes[item] > maxo:
        maxo = central_nodes[item]
        maxi = item

for node in G:
    if G.degree(node) > 4:
        print(node, G.degree(node))
# Out:
# UBA52 87.61904761904763
# TP53 34.285714285714285
# UBA52 14
# TP53 5

# %%
# Highlight central nodes
key_nodes = ['UBA52', 'TP53']
genes = open('genes_naive.txt', 'r').read().splitlines()
lines = open('subnet_edges_naive_expand.txt', 'r').read().splitlines()
for line in lines[1:]:
    temp = line.split('\t')
    
    # Differentiate input and non-input genes
    if temp[0].strip('"') in genes or temp[1].strip('"') in genes:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='green')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='blue')
    else:
        if temp[0].strip('"') in key_nodes or temp[1].strip('"') in key_nodes:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='seagreen')
        else:
            G.add_edge(temp[0].strip('"'), temp[1].strip('"'), color='gray')
            
edges = G.edges()
colors = [G[u][v]['color'] for u, v in edges]

node_map = []
color_map = []
legend_to_do = []
for node in G:
    if node.rstrip('"').lstrip('"') in genes:
        if node in key_nodes:
            color_map.append('lightgreen')
        else:
            color_map.append('lightblue')
    else:
        if node.rstrip('"').lstrip('"') in key_nodes:
            color_map.append('darkseagreen')
        else:
            color_map.append('lightgray')
legend_to_do.append(('Central nodes (input)', 'lightgreen'))
legend_to_do.append(('Central nodes (non-input)', 'darkseagreen'))
legend_to_do.append(('Input genes', 'lightblue'))
legend_to_do.append(('Non-input genes', 'lightgray'))

fig = plt.figure()
fig.set_figheight(16)
fig.set_figwidth(26)
nx.draw(G, pos=graphviz_layout(G), edges=edges, edge_color=colors, with_labels=True,
        node_color=color_map, font_size=25, node_size=2000)  

custom_lines = []
labels = []
for item in legend_to_do:
    custom_lines.append(Line2D([0], [0], color=item[1], lw=10))
    labels.append(item[0])

plt.legend(custom_lines, labels, loc=0, fontsize='xx-large')
plt.show()
